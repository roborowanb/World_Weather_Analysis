# %% [markdown]
# Weather_database

# %% [markdown]
# Deliverable 1

# %%
#Importing libraries
import random
import pandas as pd
import numpy as np

# %%
#Create a new set of 2,000 random latitudes and longitudes
lats= []
lngs= []

lats = np.random.uniform(90,-90, size=2000)
lngs = np.random.uniform(90,-90, size=2000)

lats_lngs = zip(lats, lngs)

coordinates = list(lats_lngs)

# %%
# Get the nearest city using the citipy module
from citipy import citipy


# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
print(len(cities))
# Out:
# 771

# %%
#Perform an API call with the OpenWeatherMap

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an endpoint URL for a city.
city_url = url + "&q=" + "boston"

# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 67.78,
#   'feels_like': 66.7,
#   'temp_min': 63.28,
#   'temp_max': 71.15,
#   'pressure': 1004,
#   'humidity': 52},
#  'visibility': 10000,
#  'wind': {'speed': 14.97, 'deg': 300, 'gust': 24.16},
#  'clouds': {'all': 75},
#  'dt': 1655578209,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1655543222,
#   'sunset': 1655598225},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Retrieve the following information from the API call
##Latitude and longitude
##Maximum temperature
##Percent humidity
##Percent cloudiness
##Wind speed
##Weather description (for example, clouds, fog, light rain, clear sky)


# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime


# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1



# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weatherDescription = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather Description": city_weatherDescription}
                        )

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | floro
# Processing Record 3 of Set 1 | souillac
# Processing Record 4 of Set 1 | boende
# Processing Record 5 of Set 1 | torbay
# Processing Record 6 of Set 1 | keuruu
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | cidreira
# Processing Record 9 of Set 1 | mar del plata
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | saldanha
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | almenevo
# City not found. Skipping...
# Processing Record 14 of Set 1 | arraial do cabo
# Processing Record 15 of Set 1 | ostrovnoy
# Processing Record 16 of Set 1 | victoria
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | umm lajj
# Processing Record 20 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 1 | iqaluit
# Processing Record 22 of Set 1 | lebu
# Processing Record 23 of Set 1 | mahibadhoo
# Processing Record 24 of Set 1 | ambilobe
# Processing Record 25 of Set 1 | ponta do sol
# Processing Record 26 of Set 1 | piacabucu
# Processing Record 27 of Set 1 | weligama
# Processing Record 28 of Set 1 | malakal
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | riyadh
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | mattru
# Processing Record 33 of Set 1 | atasu
# Processing Record 34 of Set 1 | ipixuna
# Processing Record 35 of Set 1 | grindavik
# Processing Record 36 of Set 1 | bulaevo
# Processing Record 37 of Set 1 | clyde river
# Processing Record 38 of Set 1 | osmaniye
# Processing Record 39 of Set 1 | saint george
# Processing Record 40 of Set 1 | saint-philippe
# Processing Record 41 of Set 1 | kyabe
# Processing Record 42 of Set 1 | nicoya
# Processing Record 43 of Set 1 | viedma
# Processing Record 44 of Set 1 | kuusamo
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | pangnirtung
# Processing Record 47 of Set 1 | ushtobe
# Processing Record 48 of Set 1 | arlit
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | georgetown
# Processing Record 1 of Set 2 | nigde
# Processing Record 2 of Set 2 | rocha
# Processing Record 3 of Set 2 | banyo
# Processing Record 4 of Set 2 | wrzesnia
# Processing Record 5 of Set 2 | salisbury
# Processing Record 6 of Set 2 | sabha
# Processing Record 7 of Set 2 | carutapera
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | suluq
# Processing Record 11 of Set 2 | east london
# Processing Record 12 of Set 2 | adre
# Processing Record 13 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 2 | bengkulu
# Processing Record 15 of Set 2 | bredasdorp
# Processing Record 16 of Set 2 | kabwe
# Processing Record 17 of Set 2 | nizhniye vyazovyye
# Processing Record 18 of Set 2 | zhezkazgan
# Processing Record 19 of Set 2 | rock sound
# Processing Record 20 of Set 2 | port elizabeth
# Processing Record 21 of Set 2 | narsaq
# Processing Record 22 of Set 2 | namibe
# Processing Record 23 of Set 2 | mwense
# Processing Record 24 of Set 2 | vardo
# Processing Record 25 of Set 2 | maldonado
# Processing Record 26 of Set 2 | gobabis
# Processing Record 27 of Set 2 | tulsipur
# Processing Record 28 of Set 2 | minas novas
# Processing Record 29 of Set 2 | upernavik
# Processing Record 30 of Set 2 | mahebourg
# Processing Record 31 of Set 2 | pedreiras
# Processing Record 32 of Set 2 | shenkursk
# Processing Record 33 of Set 2 | luderitz
# Processing Record 34 of Set 2 | ottawa
# Processing Record 35 of Set 2 | maniitsoq
# Processing Record 36 of Set 2 | tombouctou
# Processing Record 37 of Set 2 | sarishabari
# Processing Record 38 of Set 2 | touros
# Processing Record 39 of Set 2 | le port
# Processing Record 40 of Set 2 | bartica
# Processing Record 41 of Set 2 | aksay
# Processing Record 42 of Set 2 | plouzane
# Processing Record 43 of Set 2 | vada
# Processing Record 44 of Set 2 | fonte boa
# Processing Record 45 of Set 2 | olafsvik
# Processing Record 46 of Set 2 | klaksvik
# Processing Record 47 of Set 2 | wahran
# City not found. Skipping...
# Processing Record 48 of Set 2 | brae
# Processing Record 49 of Set 2 | andenes
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | severodvinsk
# Processing Record 2 of Set 3 | borovskoy
# Processing Record 3 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 3 | pindushi
# Processing Record 5 of Set 3 | roald
# Processing Record 6 of Set 3 | vangaindrano
# Processing Record 7 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 3 | rio gallegos
# Processing Record 9 of Set 3 | punta de piedra
# Processing Record 10 of Set 3 | itapetinga
# Processing Record 11 of Set 3 | nanortalik
# Processing Record 12 of Set 3 | coquimbo
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | taloda
# Processing Record 15 of Set 3 | maturin
# Processing Record 16 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 3 | jalesar
# Processing Record 18 of Set 3 | luba
# Processing Record 19 of Set 3 | dombarovskiy
# Processing Record 20 of Set 3 | virginia beach
# Processing Record 21 of Set 3 | walvis bay
# Processing Record 22 of Set 3 | mosquera
# Processing Record 23 of Set 3 | san cristobal
# Processing Record 24 of Set 3 | lagoa
# Processing Record 25 of Set 3 | dingle
# Processing Record 26 of Set 3 | matagami
# Processing Record 27 of Set 3 | gat
# Processing Record 28 of Set 3 | opobo
# City not found. Skipping...
# Processing Record 29 of Set 3 | odesskoye
# Processing Record 30 of Set 3 | beloha
# Processing Record 31 of Set 3 | bonthe
# Processing Record 32 of Set 3 | wesselsbron
# Processing Record 33 of Set 3 | graaff-reinet
# Processing Record 34 of Set 3 | rincon
# Processing Record 35 of Set 3 | abay
# Processing Record 36 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 37 of Set 3 | kalamnuri
# Processing Record 38 of Set 3 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 39 of Set 3 | lapa
# Processing Record 40 of Set 3 | dakar
# Processing Record 41 of Set 3 | port blair
# Processing Record 42 of Set 3 | gamba
# Processing Record 43 of Set 3 | lagoa da canoa
# Processing Record 44 of Set 3 | ilulissat
# Processing Record 45 of Set 3 | laguna
# Processing Record 46 of Set 3 | san manuel chaparron
# Processing Record 47 of Set 3 | chuy
# Processing Record 48 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 50 of Set 3 | qaqortoq
# Processing Record 1 of Set 4 | black river
# Processing Record 2 of Set 4 | richards bay
# Processing Record 3 of Set 4 | cayenne
# Processing Record 4 of Set 4 | muros
# Processing Record 5 of Set 4 | valdosta
# Processing Record 6 of Set 4 | meuselwitz
# Processing Record 7 of Set 4 | mahalapye
# Processing Record 8 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 4 | los llanos de aridane
# Processing Record 10 of Set 4 | carballo
# Processing Record 11 of Set 4 | paita
# Processing Record 12 of Set 4 | masuguru
# Processing Record 13 of Set 4 | jalu
# Processing Record 14 of Set 4 | codrington
# Processing Record 15 of Set 4 | san vicente de canete
# Processing Record 16 of Set 4 | igrim
# Processing Record 17 of Set 4 | montorio al vomano
# Processing Record 18 of Set 4 | changji
# Processing Record 19 of Set 4 | necochea
# Processing Record 20 of Set 4 | bandarbeyla
# Processing Record 21 of Set 4 | rawson
# Processing Record 22 of Set 4 | scunthorpe
# Processing Record 23 of Set 4 | dhangadhi
# Processing Record 24 of Set 4 | saint-augustin
# Processing Record 25 of Set 4 | panjab
# Processing Record 26 of Set 4 | asfi
# Processing Record 27 of Set 4 | tefe
# Processing Record 28 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 4 | tasiilaq
# Processing Record 30 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 4 | boca do acre
# Processing Record 32 of Set 4 | hofn
# Processing Record 33 of Set 4 | grand-santi
# Processing Record 34 of Set 4 | marabba
# Processing Record 35 of Set 4 | ugarcin
# City not found. Skipping...
# Processing Record 36 of Set 4 | santa fe
# Processing Record 37 of Set 4 | ust-koksa
# Processing Record 38 of Set 4 | turukhansk
# Processing Record 39 of Set 4 | clarence town
# Processing Record 40 of Set 4 | kavant
# City not found. Skipping...
# Processing Record 41 of Set 4 | decatur
# Processing Record 42 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 43 of Set 4 | the valley
# Processing Record 44 of Set 4 | zlitan
# Processing Record 45 of Set 4 | talas
# Processing Record 46 of Set 4 | tessalit
# Processing Record 47 of Set 4 | antofagasta
# Processing Record 48 of Set 4 | kollam
# Processing Record 49 of Set 4 | den helder
# Processing Record 50 of Set 4 | inhambane
# Processing Record 1 of Set 5 | hearst
# Processing Record 2 of Set 5 | quime
# Processing Record 3 of Set 5 | araguari
# Processing Record 4 of Set 5 | muravlenko
# Processing Record 5 of Set 5 | grand gaube
# Processing Record 6 of Set 5 | goundam
# Processing Record 7 of Set 5 | salalah
# Processing Record 8 of Set 5 | punta arenas
# Processing Record 9 of Set 5 | arsk
# Processing Record 10 of Set 5 | lourdes
# Processing Record 11 of Set 5 | gubkinskiy
# Processing Record 12 of Set 5 | koslan
# Processing Record 13 of Set 5 | belmonte
# Processing Record 14 of Set 5 | thinadhoo
# Processing Record 15 of Set 5 | toccoa
# Processing Record 16 of Set 5 | bambous virieux
# Processing Record 17 of Set 5 | ichnya
# Processing Record 18 of Set 5 | sorland
# Processing Record 19 of Set 5 | kargapolye
# City not found. Skipping...
# Processing Record 20 of Set 5 | manicore
# Processing Record 21 of Set 5 | saint-joseph
# Processing Record 22 of Set 5 | urucara
# Processing Record 23 of Set 5 | havelock
# Processing Record 24 of Set 5 | canavieiras
# Processing Record 25 of Set 5 | constitucion
# Processing Record 26 of Set 5 | mandera
# Processing Record 27 of Set 5 | butoiesti
# Processing Record 28 of Set 5 | santa rosa
# Processing Record 29 of Set 5 | manakara
# Processing Record 30 of Set 5 | serenje
# Processing Record 31 of Set 5 | kaspiyskiy
# Processing Record 32 of Set 5 | iguatemi
# Processing Record 33 of Set 5 | cockburn town
# Processing Record 34 of Set 5 | la libertad
# Processing Record 35 of Set 5 | kharp
# Processing Record 36 of Set 5 | olpad
# Processing Record 37 of Set 5 | vuktyl
# Processing Record 38 of Set 5 | saint-pierre
# Processing Record 39 of Set 5 | karakendzha
# City not found. Skipping...
# Processing Record 40 of Set 5 | rio tercero
# Processing Record 41 of Set 5 | port-gentil
# Processing Record 42 of Set 5 | camana
# Processing Record 43 of Set 5 | panama city
# Processing Record 44 of Set 5 | bonfim
# Processing Record 45 of Set 5 | shu
# Processing Record 46 of Set 5 | jabinyanah
# Processing Record 47 of Set 5 | san pedro
# Processing Record 48 of Set 5 | kavaratti
# Processing Record 49 of Set 5 | goure
# Processing Record 50 of Set 5 | sao filipe
# Processing Record 1 of Set 6 | bathsheba
# Processing Record 2 of Set 6 | stornoway
# Processing Record 3 of Set 6 | meulaboh
# Processing Record 4 of Set 6 | storforshei
# Processing Record 5 of Set 6 | veraval
# Processing Record 6 of Set 6 | yar-sale
# Processing Record 7 of Set 6 | sychevka
# Processing Record 8 of Set 6 | knokke-heist
# Processing Record 9 of Set 6 | misratah
# Processing Record 10 of Set 6 | mali
# Processing Record 11 of Set 6 | achisay
# City not found. Skipping...
# Processing Record 12 of Set 6 | cruz alta
# Processing Record 13 of Set 6 | mufumbwe
# Processing Record 14 of Set 6 | kalmunai
# Processing Record 15 of Set 6 | aksarka
# Processing Record 16 of Set 6 | bocas del toro
# Processing Record 17 of Set 6 | mitu
# Processing Record 18 of Set 6 | estelle
# Processing Record 19 of Set 6 | palera
# Processing Record 20 of Set 6 | nisia floresta
# Processing Record 21 of Set 6 | paamiut
# Processing Record 22 of Set 6 | caravelas
# Processing Record 23 of Set 6 | chalmette
# Processing Record 24 of Set 6 | escanaba
# Processing Record 25 of Set 6 | chute-aux-outardes
# Processing Record 26 of Set 6 | drummondville
# Processing Record 27 of Set 6 | coracao de jesus
# Processing Record 28 of Set 6 | adrar
# Processing Record 29 of Set 6 | orhei
# Processing Record 30 of Set 6 | ilebo
# Processing Record 31 of Set 6 | mount pleasant
# Processing Record 32 of Set 6 | hurghada
# Processing Record 33 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 6 | langarud
# Processing Record 35 of Set 6 | kumo
# Processing Record 36 of Set 6 | mizdah
# Processing Record 37 of Set 6 | comodoro rivadavia
# Processing Record 38 of Set 6 | ardistan
# City not found. Skipping...
# Processing Record 39 of Set 6 | kuryk
# Processing Record 40 of Set 6 | betare oya
# Processing Record 41 of Set 6 | marsh harbour
# Processing Record 42 of Set 6 | bilma
# Processing Record 43 of Set 6 | vila franca do campo
# Processing Record 44 of Set 6 | synya
# Processing Record 45 of Set 6 | taoudenni
# Processing Record 46 of Set 6 | burewala
# Processing Record 47 of Set 6 | gollere
# City not found. Skipping...
# Processing Record 48 of Set 6 | canguaretama
# Processing Record 49 of Set 6 | mehamn
# Processing Record 50 of Set 6 | bingol
# Processing Record 1 of Set 7 | ondjiva
# Processing Record 2 of Set 7 | oistins
# Processing Record 3 of Set 7 | avdiyivka
# Processing Record 4 of Set 7 | la sarre
# Processing Record 5 of Set 7 | rayachoti
# Processing Record 6 of Set 7 | voka
# Processing Record 7 of Set 7 | manthani
# Processing Record 8 of Set 7 | camacha
# Processing Record 9 of Set 7 | nouadhibou
# Processing Record 10 of Set 7 | am timan
# Processing Record 11 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 7 | kushmurun
# Processing Record 13 of Set 7 | hwange
# Processing Record 14 of Set 7 | sorata
# Processing Record 15 of Set 7 | kasongo-lunda
# Processing Record 16 of Set 7 | lawrenceburg
# Processing Record 17 of Set 7 | porto novo
# Processing Record 18 of Set 7 | carmelo
# Processing Record 19 of Set 7 | bahia blanca
# Processing Record 20 of Set 7 | manadhoo
# Processing Record 21 of Set 7 | pucara
# Processing Record 22 of Set 7 | beni
# Processing Record 23 of Set 7 | aswan
# Processing Record 24 of Set 7 | sisimiut
# Processing Record 25 of Set 7 | pemba
# Processing Record 26 of Set 7 | vila velha
# Processing Record 27 of Set 7 | saint anthony
# Processing Record 28 of Set 7 | cabedelo
# Processing Record 29 of Set 7 | muzhi
# Processing Record 30 of Set 7 | bastia
# Processing Record 31 of Set 7 | brigantine
# Processing Record 32 of Set 7 | la rioja
# Processing Record 33 of Set 7 | zuenoula
# Processing Record 34 of Set 7 | rawah
# Processing Record 35 of Set 7 | khandbari
# Processing Record 36 of Set 7 | chicama
# Processing Record 37 of Set 7 | delfzijl
# Processing Record 38 of Set 7 | najran
# Processing Record 39 of Set 7 | jiblah
# Processing Record 40 of Set 7 | maltahohe
# Processing Record 41 of Set 7 | praia da vitoria
# Processing Record 42 of Set 7 | garowe
# Processing Record 43 of Set 7 | faya
# Processing Record 44 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 7 | jalalabad
# Processing Record 46 of Set 7 | vilhena
# Processing Record 47 of Set 7 | luanda
# Processing Record 48 of Set 7 | harper
# Processing Record 49 of Set 7 | berlevag
# Processing Record 50 of Set 7 | lasa
# Processing Record 1 of Set 8 | sao joao da barra
# Processing Record 2 of Set 8 | birsk
# Processing Record 3 of Set 8 | tabarqah
# City not found. Skipping...
# Processing Record 4 of Set 8 | saint-francois
# Processing Record 5 of Set 8 | tazovskiy
# Processing Record 6 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 7 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 8 | chitral
# Processing Record 9 of Set 8 | kaabong
# Processing Record 10 of Set 8 | nowa ruda
# Processing Record 11 of Set 8 | diego de almagro
# Processing Record 12 of Set 8 | lebedyn
# Processing Record 13 of Set 8 | bonavista
# Processing Record 14 of Set 8 | puerto rico
# Processing Record 15 of Set 8 | sarkand
# Processing Record 16 of Set 8 | luquillo
# Processing Record 17 of Set 8 | higuey
# City not found. Skipping...
# Processing Record 18 of Set 8 | lima
# Processing Record 19 of Set 8 | jurado
# Processing Record 20 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 21 of Set 8 | santa maria
# Processing Record 22 of Set 8 | makokou
# Processing Record 23 of Set 8 | olivenza
# Processing Record 24 of Set 8 | alipur
# Processing Record 25 of Set 8 | alvinopolis
# Processing Record 26 of Set 8 | waw
# Processing Record 27 of Set 8 | aybak
# City not found. Skipping...
# Processing Record 28 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 8 | catamarca
# Processing Record 30 of Set 8 | lere
# Processing Record 31 of Set 8 | bubaque
# Processing Record 32 of Set 8 | tripoli
# Processing Record 33 of Set 8 | mayor pablo lagerenza
# Processing Record 34 of Set 8 | peniche
# Processing Record 35 of Set 8 | ovre ardal
# Processing Record 36 of Set 8 | wanlaweyn
# Processing Record 37 of Set 8 | wiarton
# Processing Record 38 of Set 8 | santa cruz
# Processing Record 39 of Set 8 | hamilton
# Processing Record 40 of Set 8 | ordzhonikidze
# Processing Record 41 of Set 8 | teguldet
# Processing Record 42 of Set 8 | santa vitoria do palmar
# Processing Record 43 of Set 8 | ormara
# Processing Record 44 of Set 8 | ponta delgada
# Processing Record 45 of Set 8 | la palma
# Processing Record 46 of Set 8 | myskhako
# Processing Record 47 of Set 8 | tete
# Processing Record 48 of Set 8 | hit
# Processing Record 49 of Set 8 | yabrud
# Processing Record 50 of Set 8 | guarapari
# Processing Record 1 of Set 9 | sakakah
# Processing Record 2 of Set 9 | shubarkuduk
# Processing Record 3 of Set 9 | sokoni
# Processing Record 4 of Set 9 | tabou
# Processing Record 5 of Set 9 | tres arroyos
# Processing Record 6 of Set 9 | rio bueno
# Processing Record 7 of Set 9 | businga
# Processing Record 8 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 9 | lieto
# Processing Record 10 of Set 9 | uyuni
# Processing Record 11 of Set 9 | gornyy
# Processing Record 12 of Set 9 | kalemie
# Processing Record 13 of Set 9 | tritenii de jos
# Processing Record 14 of Set 9 | bandar-e lengeh
# Processing Record 15 of Set 9 | mogadishu
# Processing Record 16 of Set 9 | korla
# Processing Record 17 of Set 9 | kathmandu
# Processing Record 18 of Set 9 | kruisfontein
# Processing Record 19 of Set 9 | biltine
# Processing Record 20 of Set 9 | stokmarknes
# Processing Record 21 of Set 9 | dwarka
# Processing Record 22 of Set 9 | holme
# Processing Record 23 of Set 9 | morondava
# Processing Record 24 of Set 9 | teguise
# Processing Record 25 of Set 9 | lamu
# Processing Record 26 of Set 9 | moose factory
# Processing Record 27 of Set 9 | bom jesus
# Processing Record 28 of Set 9 | zambezi
# Processing Record 29 of Set 9 | savannah bight
# Processing Record 30 of Set 9 | mecca
# Processing Record 31 of Set 9 | salmas
# Processing Record 32 of Set 9 | valentigney
# Processing Record 33 of Set 9 | canico
# Processing Record 34 of Set 9 | traverse city
# Processing Record 35 of Set 9 | miranorte
# City not found. Skipping...
# Processing Record 36 of Set 9 | mayumba
# Processing Record 37 of Set 9 | rutana
# Processing Record 38 of Set 9 | sayat
# Processing Record 39 of Set 9 | hobe sound
# Processing Record 40 of Set 9 | namwala
# Processing Record 41 of Set 9 | kortkeros
# Processing Record 42 of Set 9 | trzebiatow
# Processing Record 43 of Set 9 | aleksandrovskoye
# Processing Record 44 of Set 9 | awjilah
# Processing Record 45 of Set 9 | dzilam gonzalez
# Processing Record 46 of Set 9 | fereydun kenar
# Processing Record 47 of Set 9 | atar
# Processing Record 48 of Set 9 | anloga
# Processing Record 49 of Set 9 | podgornoye
# Processing Record 50 of Set 9 | quatre cocos
# Processing Record 1 of Set 10 | el prat de llobregat
# Processing Record 2 of Set 10 | balkhash
# Processing Record 3 of Set 10 | volchikha
# Processing Record 4 of Set 10 | kaina
# Processing Record 5 of Set 10 | nizwa
# Processing Record 6 of Set 10 | coihaique
# Processing Record 7 of Set 10 | dori
# Processing Record 8 of Set 10 | minudasht
# Processing Record 9 of Set 10 | sinnamary
# Processing Record 10 of Set 10 | pimentel
# Processing Record 11 of Set 10 | oriximina
# Processing Record 12 of Set 10 | nara
# Processing Record 13 of Set 10 | bukene
# Processing Record 14 of Set 10 | portree
# Processing Record 15 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 10 | pavda
# City not found. Skipping...
# Processing Record 17 of Set 10 | waycross
# Processing Record 18 of Set 10 | urubicha
# Processing Record 19 of Set 10 | huarmey
# Processing Record 20 of Set 10 | derzhavinsk
# Processing Record 21 of Set 10 | ankazobe
# Processing Record 22 of Set 10 | camopi
# Processing Record 23 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 24 of Set 10 | zopilotepe
# Processing Record 25 of Set 10 | ancud
# Processing Record 26 of Set 10 | hambantota
# Processing Record 27 of Set 10 | havre-saint-pierre
# Processing Record 28 of Set 10 | challapata
# Processing Record 29 of Set 10 | bardiyah
# Processing Record 30 of Set 10 | uruzgan
# Processing Record 31 of Set 10 | moquegua
# Processing Record 32 of Set 10 | boa vista
# Processing Record 33 of Set 10 | shepsi
# Processing Record 34 of Set 10 | revda
# Processing Record 35 of Set 10 | kansanshi
# Processing Record 36 of Set 10 | springdale
# Processing Record 37 of Set 10 | alta floresta
# Processing Record 38 of Set 10 | skjervoy
# Processing Record 39 of Set 10 | leticia
# Processing Record 40 of Set 10 | acin
# City not found. Skipping...
# Processing Record 41 of Set 10 | moiyabana
# City not found. Skipping...
# Processing Record 42 of Set 10 | saint-georges
# Processing Record 43 of Set 10 | willowmore
# Processing Record 44 of Set 10 | asosa
# Processing Record 45 of Set 10 | japura
# Processing Record 46 of Set 10 | praia
# Processing Record 47 of Set 10 | cedar lake
# Processing Record 48 of Set 10 | mushie
# Processing Record 49 of Set 10 | esna
# Processing Record 50 of Set 10 | keti bandar
# Processing Record 1 of Set 11 | husavik
# Processing Record 2 of Set 11 | gemena
# Processing Record 3 of Set 11 | largo
# Processing Record 4 of Set 11 | majalgaon
# Processing Record 5 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 6 of Set 11 | odweyne
# Processing Record 7 of Set 11 | solwezi
# Processing Record 8 of Set 11 | scarborough
# Processing Record 9 of Set 11 | axim
# Processing Record 10 of Set 11 | azul
# Processing Record 11 of Set 11 | bonga
# Processing Record 12 of Set 11 | mesetas
# Processing Record 13 of Set 11 | tarauaca
# Processing Record 14 of Set 11 | chabahar
# Processing Record 15 of Set 11 | samsun
# Processing Record 16 of Set 11 | mundra
# Processing Record 17 of Set 11 | sechura
# Processing Record 18 of Set 11 | dudinka
# Processing Record 19 of Set 11 | mercedes
# Processing Record 20 of Set 11 | sindou
# Processing Record 21 of Set 11 | mustafabad
# Processing Record 22 of Set 11 | thilogne
# City not found. Skipping...
# Processing Record 23 of Set 11 | sikonge
# Processing Record 24 of Set 11 | monte alegre
# Processing Record 25 of Set 11 | porto walter
# Processing Record 26 of Set 11 | mocuba
# Processing Record 27 of Set 11 | abu dhabi
# Processing Record 28 of Set 11 | marienburg
# Processing Record 29 of Set 11 | louga
# Processing Record 30 of Set 11 | middletown
# Processing Record 31 of Set 11 | huntsville
# Processing Record 32 of Set 11 | sangueya
# Processing Record 33 of Set 11 | ust-kulom
# Processing Record 34 of Set 11 | voznesenskaya
# Processing Record 35 of Set 11 | puerto del rosario
# Processing Record 36 of Set 11 | werda
# Processing Record 37 of Set 11 | vila do maio
# Processing Record 38 of Set 11 | manga
# Processing Record 39 of Set 11 | prudentopolis
# Processing Record 40 of Set 11 | gayeri
# Processing Record 41 of Set 11 | pisco
# Processing Record 42 of Set 11 | talnakh
# Processing Record 43 of Set 11 | lidkoping
# Processing Record 44 of Set 11 | tekeli
# Processing Record 45 of Set 11 | bognor regis
# Processing Record 46 of Set 11 | liverpool
# Processing Record 47 of Set 11 | araouane
# Processing Record 48 of Set 11 | santiago
# Processing Record 49 of Set 11 | deer lake
# Processing Record 50 of Set 11 | burica
# City not found. Skipping...
# Processing Record 1 of Set 12 | mwinilunga
# Processing Record 2 of Set 12 | dundalk
# Processing Record 3 of Set 12 | olinda
# Processing Record 4 of Set 12 | clacton-on-sea
# Processing Record 5 of Set 12 | kumasi
# Processing Record 6 of Set 12 | inta
# Processing Record 7 of Set 12 | sept-iles
# Processing Record 8 of Set 12 | sandnessjoen
# Processing Record 9 of Set 12 | yomou
# Processing Record 10 of Set 12 | manono
# Processing Record 11 of Set 12 | marsa matruh
# Processing Record 12 of Set 12 | urumqi
# Processing Record 13 of Set 12 | wajid
# Processing Record 14 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 12 | wattegama
# Processing Record 16 of Set 12 | yazykovo
# Processing Record 17 of Set 12 | ongandjera
# Processing Record 18 of Set 12 | saint-raymond
# Processing Record 19 of Set 12 | rio grande
# Processing Record 20 of Set 12 | chone
# Processing Record 21 of Set 12 | butembo
# Processing Record 22 of Set 12 | karpathos
# Processing Record 23 of Set 12 | louis trichardt
# Processing Record 24 of Set 12 | sistranda
# Processing Record 25 of Set 12 | punto fijo
# Processing Record 26 of Set 12 | renfrew
# Processing Record 27 of Set 12 | vigrestad
# Processing Record 28 of Set 12 | port-cartier
# Processing Record 29 of Set 12 | catia la mar
# Processing Record 30 of Set 12 | tsumeb
# Processing Record 31 of Set 12 | dieppe
# Processing Record 32 of Set 12 | porto murtinho
# Processing Record 33 of Set 12 | haradok
# Processing Record 34 of Set 12 | shinpokh
# Processing Record 35 of Set 12 | jacareacanga
# Processing Record 36 of Set 12 | nnewi
# Processing Record 37 of Set 12 | mahanoro
# Processing Record 38 of Set 12 | mantua
# Processing Record 39 of Set 12 | ivangorod
# Processing Record 40 of Set 12 | rio pomba
# Processing Record 41 of Set 12 | veinticinco de mayo
# Processing Record 42 of Set 12 | hobyo
# Processing Record 43 of Set 12 | pedro juan caballero
# Processing Record 44 of Set 12 | zavetnoye
# Processing Record 45 of Set 12 | vestmannaeyjar
# Processing Record 46 of Set 12 | eyl
# Processing Record 47 of Set 12 | moundsville
# Processing Record 48 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 49 of Set 12 | qobustan
# Processing Record 50 of Set 12 | svetlyy
# Processing Record 1 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 2 of Set 13 | koscian
# Processing Record 3 of Set 13 | albany
# Processing Record 4 of Set 13 | wiwili
# Processing Record 5 of Set 13 | oranjemund
# Processing Record 6 of Set 13 | kralendijk
# Processing Record 7 of Set 13 | aden
# Processing Record 8 of Set 13 | le pont-de-claix
# Processing Record 9 of Set 13 | sioux lookout
# Processing Record 10 of Set 13 | nata
# Processing Record 11 of Set 13 | yarmouth
# Processing Record 12 of Set 13 | pauini
# Processing Record 13 of Set 13 | conakry
# Processing Record 14 of Set 13 | baza
# Processing Record 15 of Set 13 | atbasar
# Processing Record 16 of Set 13 | san ignacio
# Processing Record 17 of Set 13 | tshikapa
# Processing Record 18 of Set 13 | sokolo
# Processing Record 19 of Set 13 | chaman
# Processing Record 20 of Set 13 | laje
# Processing Record 21 of Set 13 | havoysund
# Processing Record 22 of Set 13 | bedi
# Processing Record 23 of Set 13 | manaquiri
# Processing Record 24 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 25 of Set 13 | thompson
# Processing Record 26 of Set 13 | itarema
# Processing Record 27 of Set 13 | shihezi
# Processing Record 28 of Set 13 | wasserburg
# Processing Record 29 of Set 13 | yenagoa
# Processing Record 30 of Set 13 | puerto ayacucho
# Processing Record 31 of Set 13 | miastko
# Processing Record 32 of Set 13 | krasnoselkup
# Processing Record 33 of Set 13 | bay roberts
# Processing Record 34 of Set 13 | ipameri
# Processing Record 35 of Set 13 | bollnas
# Processing Record 36 of Set 13 | iquique
# Processing Record 37 of Set 13 | vasterhaninge
# Processing Record 38 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 39 of Set 13 | talcahuano
# Processing Record 40 of Set 13 | canton
# Processing Record 41 of Set 13 | bure
# Processing Record 42 of Set 13 | almenara
# Processing Record 43 of Set 13 | guaimaca
# Processing Record 44 of Set 13 | turayf
# Processing Record 45 of Set 13 | pitimbu
# Processing Record 46 of Set 13 | fomboni
# Processing Record 47 of Set 13 | cururupu
# Processing Record 48 of Set 13 | woodstock
# Processing Record 49 of Set 13 | foumban
# Processing Record 50 of Set 13 | ji-parana
# City not found. Skipping...
# Processing Record 1 of Set 14 | marrakesh
# Processing Record 2 of Set 14 | nalut
# Processing Record 3 of Set 14 | amapa
# Processing Record 4 of Set 14 | kemi
# Processing Record 5 of Set 14 | marigot
# Processing Record 6 of Set 14 | portage
# Processing Record 7 of Set 14 | altamira
# Processing Record 8 of Set 14 | tiznit
# Processing Record 9 of Set 14 | chorozinho
# Processing Record 10 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 11 of Set 14 | mafinga
# Processing Record 12 of Set 14 | baran
# Processing Record 13 of Set 14 | dzierzoniow
# Processing Record 14 of Set 14 | susehri
# Processing Record 15 of Set 14 | chany
# Processing Record 16 of Set 14 | youghal
# Processing Record 17 of Set 14 | george town
# Processing Record 18 of Set 14 | harer
# Processing Record 19 of Set 14 | ust-tsilma
# Processing Record 20 of Set 14 | oussouye
# Processing Record 21 of Set 14 | marysville
# Processing Record 22 of Set 14 | carlibaba
# Processing Record 23 of Set 14 | porto santo
# Processing Record 24 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 25 of Set 14 | asyut
# Processing Record 26 of Set 14 | xai-xai
# Processing Record 27 of Set 14 | hammerfest
# Processing Record 28 of Set 14 | ayios kirikos
# City not found. Skipping...
# Processing Record 29 of Set 14 | karatau
# Processing Record 30 of Set 14 | salta
# Processing Record 31 of Set 14 | lagunas
# Processing Record 32 of Set 14 | ocho rios
# Processing Record 33 of Set 14 | ercis
# Processing Record 34 of Set 14 | jumla
# Processing Record 35 of Set 14 | correntina
# Processing Record 36 of Set 14 | dolgorukovo
# Processing Record 37 of Set 14 | balsas
# Processing Record 38 of Set 14 | bushehr
# Processing Record 39 of Set 14 | geraldton
# Processing Record 40 of Set 14 | seredka
# Processing Record 41 of Set 14 | raisio
# Processing Record 42 of Set 14 | valverde del camino
# Processing Record 43 of Set 14 | barra do bugres
# Processing Record 44 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 14 | tucuman
# Processing Record 46 of Set 14 | callaway
# Processing Record 47 of Set 14 | guane
# Processing Record 48 of Set 14 | arroyo
# Processing Record 49 of Set 14 | las palmas
# Processing Record 50 of Set 14 | ystad
# Processing Record 1 of Set 15 | leh
# Processing Record 2 of Set 15 | balkanabat
# Processing Record 3 of Set 15 | mangrol
# Processing Record 4 of Set 15 | norway
# Processing Record 5 of Set 15 | henties bay
# Processing Record 6 of Set 15 | aguilas
# Processing Record 7 of Set 15 | kanniyakumari
# Processing Record 8 of Set 15 | conde
# Processing Record 9 of Set 15 | alta
# Processing Record 10 of Set 15 | damietta
# Processing Record 11 of Set 15 | astipalaia
# City not found. Skipping...
# Processing Record 12 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 13 of Set 15 | kaniama
# Processing Record 14 of Set 15 | saurimo
# Processing Record 15 of Set 15 | osypenko
# Processing Record 16 of Set 15 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 17 of Set 15 | hamadan
# Processing Record 18 of Set 15 | dondo
# Processing Record 19 of Set 15 | beira
# Processing Record 20 of Set 15 | pokaran
# Processing Record 21 of Set 15 | cobourg
# Processing Record 22 of Set 15 | lewisporte
# Processing Record 23 of Set 15 | bethal
# Processing Record 24 of Set 15 | akom
# Processing Record 25 of Set 15 | andilamena
# Processing Record 26 of Set 15 | bar harbor
# Processing Record 27 of Set 15 | kizema
# Processing Record 28 of Set 15 | neftcala
# Processing Record 29 of Set 15 | severnyy
# Processing Record 30 of Set 15 | cravo norte
# Processing Record 31 of Set 15 | calamar
# Processing Record 32 of Set 15 | kabalo
# Processing Record 33 of Set 15 | vallenar
# Processing Record 34 of Set 15 | reconquista
# Processing Record 35 of Set 15 | barahona
# Processing Record 36 of Set 15 | ati
# Processing Record 37 of Set 15 | wilmington
# Processing Record 38 of Set 15 | telsiai
# Processing Record 39 of Set 15 | czluchow
# Processing Record 40 of Set 15 | yumbo
# Processing Record 41 of Set 15 | bandrele
# Processing Record 42 of Set 15 | minab
# Processing Record 43 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 44 of Set 15 | morro da fumaca
# Processing Record 45 of Set 15 | morant bay
# Processing Record 46 of Set 15 | muzambinho
# Processing Record 47 of Set 15 | salekhard
# Processing Record 48 of Set 15 | vryburg
# Processing Record 49 of Set 15 | chimbote
# Processing Record 50 of Set 15 | santa cruz del norte
# Processing Record 1 of Set 16 | laurel
# Processing Record 2 of Set 16 | linhares
# Processing Record 3 of Set 16 | boke
# Processing Record 4 of Set 16 | visnes
# Processing Record 5 of Set 16 | naugarzan
# City not found. Skipping...
# Processing Record 6 of Set 16 | talladega
# Processing Record 7 of Set 16 | tome
# Processing Record 8 of Set 16 | pizarro
# Processing Record 9 of Set 16 | tukrah
# Processing Record 10 of Set 16 | pucallpa
# Processing Record 11 of Set 16 | navlya
# Processing Record 12 of Set 16 | lithakia
# Processing Record 13 of Set 16 | imbituba
# Processing Record 14 of Set 16 | kano
# Processing Record 15 of Set 16 | polunochnoye
# Processing Record 16 of Set 16 | nuuk
# Processing Record 17 of Set 16 | puerto baquerizo moreno
# Processing Record 18 of Set 16 | gangotri
# City not found. Skipping...
# Processing Record 19 of Set 16 | oschersleben
# Processing Record 20 of Set 16 | bindura
# Processing Record 21 of Set 16 | kanash
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Add the data to a new DataFrame.

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

new_column_order = ["City", "Country", "Lat", "Lng","Date","Max Temp","Humidity","Cloudiness","Wind Speed", "Weather Description"]
city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#             City Country      Lat      Lng                 Date  Max Temp  \
# 0        Ushuaia      AR -54.8000 -68.3000  2022-06-18 18:50:09     29.86
# 1          Floro      NO  61.5996   5.0328  2022-06-18 18:50:09     53.56
# 2       Souillac      MU -20.5167  57.5167  2022-06-18 18:50:10     68.38
# 3         Boende      CD  -0.2167  20.8667  2022-06-18 18:50:10     70.29
# 4         Torbay      CA  47.6666 -52.7314  2022-06-18 18:50:11     63.37
# 5         Keuruu      FI  62.2667  24.7000  2022-06-18 18:50:11     57.79
# 6       Hermanus      ZA -34.4187  19.2345  2022-06-18 18:50:11     50.81
# 7       Cidreira      BR -30.1811 -50.2056  2022-06-18 18:47:01     53.78
# 8  Mar Del Plata      AR -38.0023 -57.5575  2022-06-18 18:49:08     56.08
# 9       Saldanha      ZA -33.0117  17.9442  2022-06-18 18:50:12     55.45
#
#    Humidity  Cloudiness  Wind Speed Weather Description
# 0        86          40       18.41         shower snow
# 1        71          75       24.16       broken clouds
# 2        88          40        8.05    scattered clouds
# 3        93          96        0.63     overcast clouds
# 4        64          75       28.77       broken clouds
# 5        98         100        5.35     overcast clouds
# 6        77           5       14.61          light rain
# 7        57           2       13.24           clear sky
# 8        45           0       13.80           clear sky
# 9        69          12        9.42          few clouds

# %%
#Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# Create the output file (CSV).
output_data_file = "Weather_database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
