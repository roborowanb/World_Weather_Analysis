# %% [markdown]
# Weather_database

# %% [markdown]
# Deliverable 1

# %%
#Importing libraries
import random
import pandas as pd
import numpy as np

# %%
#Create a new set of 2,000 random latitudes and longitudes
lats= []
lngs= []

lats = np.random.uniform(90,-90, size=2000)
lngs = np.random.uniform(90,-90, size=2000)

lats_lngs = zip(lats, lngs)

coordinates = list(lats_lngs)

# %%
# Get the nearest city using the citipy module
from citipy import citipy


# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
print(len(cities))
# Out:
# 780

# %%
#Perform an API call with the OpenWeatherMap

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an endpoint URL for a city.
city_url = url + "&q=" + "boston"

# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 67.51,
#   'feels_like': 66.42,
#   'temp_min': 62.92,
#   'temp_max': 71.51,
#   'pressure': 1003,
#   'humidity': 52},
#  'visibility': 10000,
#  'wind': {'speed': 11.99, 'deg': 0, 'gust': 0},
#  'clouds': {'all': 96},
#  'dt': 1655574950,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1655543222,
#   'sunset': 1655598225},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Retrieve the following information from the API call
##Latitude and longitude
##Maximum temperature
##Percent humidity
##Percent cloudiness
##Wind speed
##Weather description (for example, clouds, fog, light rain, clear sky)


# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime


# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1



# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weatherDescription = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather Description": city_weatherDescription}
                        )

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 1 | coquimbo
# Processing Record 3 of Set 1 | ponta do sol
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | suamico
# Processing Record 6 of Set 1 | durania
# Processing Record 7 of Set 1 | poddorye
# Processing Record 8 of Set 1 | upernavik
# Processing Record 9 of Set 1 | qaanaaq
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | vila velha
# Processing Record 13 of Set 1 | lenti
# Processing Record 14 of Set 1 | laguna
# Processing Record 15 of Set 1 | itarema
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | chuy
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | sumbe
# Processing Record 20 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 1 | husavik
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | souillac
# Processing Record 24 of Set 1 | riyadh
# Processing Record 25 of Set 1 | la asuncion
# Processing Record 26 of Set 1 | gat
# Processing Record 27 of Set 1 | clyde river
# Processing Record 28 of Set 1 | umm lajj
# Processing Record 29 of Set 1 | takoradi
# Processing Record 30 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | camacha
# Processing Record 33 of Set 1 | dedovichi
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | concepcion
# Processing Record 36 of Set 1 | chivay
# Processing Record 37 of Set 1 | nieuw nickerie
# Processing Record 38 of Set 1 | auburndale
# Processing Record 39 of Set 1 | beruni
# City not found. Skipping...
# Processing Record 40 of Set 1 | georgetown
# Processing Record 41 of Set 1 | easton
# Processing Record 42 of Set 1 | mahebourg
# Processing Record 43 of Set 1 | nanortalik
# Processing Record 44 of Set 1 | havre-saint-pierre
# Processing Record 45 of Set 1 | gulu
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | saint-philippe
# Processing Record 48 of Set 1 | hluti
# Processing Record 49 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 1 | tevriz
# Processing Record 1 of Set 2 | kautokeino
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | huarmey
# Processing Record 4 of Set 2 | stornoway
# Processing Record 5 of Set 2 | tessalit
# Processing Record 6 of Set 2 | lagoa
# Processing Record 7 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 2 | amapa
# Processing Record 9 of Set 2 | antalaha
# Processing Record 10 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | neuquen
# Processing Record 13 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 2 | gidam
# Processing Record 15 of Set 2 | marzuq
# Processing Record 16 of Set 2 | the valley
# Processing Record 17 of Set 2 | victoria
# Processing Record 18 of Set 2 | kutum
# Processing Record 19 of Set 2 | duayaw nkwanta
# Processing Record 20 of Set 2 | sao paulo de olivenca
# Processing Record 21 of Set 2 | haapsalu
# Processing Record 22 of Set 2 | izhma
# Processing Record 23 of Set 2 | thinadhoo
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | tasiilaq
# Processing Record 26 of Set 2 | vila franca do campo
# Processing Record 27 of Set 2 | kathmandu
# Processing Record 28 of Set 2 | codrington
# Processing Record 29 of Set 2 | bathsheba
# Processing Record 30 of Set 2 | pemba
# Processing Record 31 of Set 2 | lima
# Processing Record 32 of Set 2 | longyearbyen
# Processing Record 33 of Set 2 | ostersund
# Processing Record 34 of Set 2 | chimbote
# Processing Record 35 of Set 2 | viedma
# Processing Record 36 of Set 2 | pailon
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | kuytun
# Processing Record 39 of Set 2 | paamiut
# Processing Record 40 of Set 2 | acarau
# Processing Record 41 of Set 2 | kapoeta
# Processing Record 42 of Set 2 | alta floresta
# Processing Record 43 of Set 2 | erdemli
# Processing Record 44 of Set 2 | busselton
# Processing Record 45 of Set 2 | kruisfontein
# Processing Record 46 of Set 2 | cape town
# Processing Record 47 of Set 2 | toguchin
# Processing Record 48 of Set 2 | faya
# Processing Record 49 of Set 2 | san carlos de bariloche
# Processing Record 50 of Set 2 | morondava
# Processing Record 1 of Set 3 | vestmannaeyjar
# Processing Record 2 of Set 3 | islampur
# Processing Record 3 of Set 3 | salinopolis
# Processing Record 4 of Set 3 | fiumicino
# Processing Record 5 of Set 3 | pangnirtung
# Processing Record 6 of Set 3 | manacapuru
# Processing Record 7 of Set 3 | usinsk
# Processing Record 8 of Set 3 | dikson
# Processing Record 9 of Set 3 | havoysund
# Processing Record 10 of Set 3 | margate
# Processing Record 11 of Set 3 | derzhavinsk
# Processing Record 12 of Set 3 | ormara
# Processing Record 13 of Set 3 | los llanos de aridane
# Processing Record 14 of Set 3 | gashua
# Processing Record 15 of Set 3 | ampanihy
# Processing Record 16 of Set 3 | tromso
# Processing Record 17 of Set 3 | namibe
# Processing Record 18 of Set 3 | bambous virieux
# Processing Record 19 of Set 3 | sao joao da barra
# Processing Record 20 of Set 3 | aboso
# Processing Record 21 of Set 3 | sur
# Processing Record 22 of Set 3 | valjala
# City not found. Skipping...
# Processing Record 23 of Set 3 | taltal
# Processing Record 24 of Set 3 | hamilton
# Processing Record 25 of Set 3 | verkhovazhye
# Processing Record 26 of Set 3 | inirida
# Processing Record 27 of Set 3 | saldanha
# Processing Record 28 of Set 3 | yar-sale
# Processing Record 29 of Set 3 | aswan
# Processing Record 30 of Set 3 | eydhafushi
# Processing Record 31 of Set 3 | belmonte
# Processing Record 32 of Set 3 | san juan
# Processing Record 33 of Set 3 | bereda
# Processing Record 34 of Set 3 | nijar
# Processing Record 35 of Set 3 | ivanava
# Processing Record 36 of Set 3 | puerto leguizamo
# Processing Record 37 of Set 3 | brigantine
# Processing Record 38 of Set 3 | luderitz
# Processing Record 39 of Set 3 | santiago del estero
# Processing Record 40 of Set 3 | hobyo
# Processing Record 41 of Set 3 | livani
# Processing Record 42 of Set 3 | sao francisco
# Processing Record 43 of Set 3 | hammerfest
# Processing Record 44 of Set 3 | masuguru
# Processing Record 45 of Set 3 | berlevag
# Processing Record 46 of Set 3 | humberto de campos
# Processing Record 47 of Set 3 | cerinza
# Processing Record 48 of Set 3 | koungheul
# Processing Record 49 of Set 3 | stokke
# Processing Record 50 of Set 3 | outjo
# Processing Record 1 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 2 of Set 4 | yorosso
# Processing Record 3 of Set 4 | isiro
# Processing Record 4 of Set 4 | encruzilhada do sul
# Processing Record 5 of Set 4 | dolny kubin
# Processing Record 6 of Set 4 | talavera de la reina
# Processing Record 7 of Set 4 | gambela
# Processing Record 8 of Set 4 | mubi
# Processing Record 9 of Set 4 | marawi
# Processing Record 10 of Set 4 | dinsor
# City not found. Skipping...
# Processing Record 11 of Set 4 | mezen
# Processing Record 12 of Set 4 | abnub
# Processing Record 13 of Set 4 | marrakesh
# Processing Record 14 of Set 4 | mchinji
# Processing Record 15 of Set 4 | udimskiy
# Processing Record 16 of Set 4 | caravelas
# Processing Record 17 of Set 4 | mlowo
# Processing Record 18 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 4 | dakar
# Processing Record 20 of Set 4 | maxixe
# Processing Record 21 of Set 4 | samana
# Processing Record 22 of Set 4 | changji
# Processing Record 23 of Set 4 | kalmunai
# Processing Record 24 of Set 4 | jalu
# Processing Record 25 of Set 4 | svetlogorsk
# Processing Record 26 of Set 4 | hambantota
# Processing Record 27 of Set 4 | ponta delgada
# Processing Record 28 of Set 4 | batticaloa
# Processing Record 29 of Set 4 | ogbomosho
# Processing Record 30 of Set 4 | katima mulilo
# Processing Record 31 of Set 4 | porto walter
# Processing Record 32 of Set 4 | lebu
# Processing Record 33 of Set 4 | robertsport
# Processing Record 34 of Set 4 | ancud
# Processing Record 35 of Set 4 | pisco
# Processing Record 36 of Set 4 | cabedelo
# Processing Record 37 of Set 4 | port blair
# Processing Record 38 of Set 4 | saint-georges
# Processing Record 39 of Set 4 | najran
# Processing Record 40 of Set 4 | coihaique
# Processing Record 41 of Set 4 | tiznit
# Processing Record 42 of Set 4 | karaton
# Processing Record 43 of Set 4 | sambalpur
# Processing Record 44 of Set 4 | fuerte olimpo
# Processing Record 45 of Set 4 | melbu
# Processing Record 46 of Set 4 | sinnamary
# Processing Record 47 of Set 4 | cidreira
# Processing Record 48 of Set 4 | dupnica
# City not found. Skipping...
# Processing Record 49 of Set 4 | richard toll
# City not found. Skipping...
# Processing Record 50 of Set 4 | karonga
# Processing Record 1 of Set 5 | beloha
# Processing Record 2 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 3 of Set 5 | soma
# Processing Record 4 of Set 5 | manicore
# Processing Record 5 of Set 5 | dingle
# Processing Record 6 of Set 5 | chicama
# Processing Record 7 of Set 5 | torbay
# Processing Record 8 of Set 5 | palasa
# Processing Record 9 of Set 5 | nalut
# Processing Record 10 of Set 5 | kasamwa
# Processing Record 11 of Set 5 | korla
# Processing Record 12 of Set 5 | xuddur
# Processing Record 13 of Set 5 | elmina
# Processing Record 14 of Set 5 | catacaos
# Processing Record 15 of Set 5 | castro
# Processing Record 16 of Set 5 | mana
# Processing Record 17 of Set 5 | porto nacional
# Processing Record 18 of Set 5 | rybachiy
# Processing Record 19 of Set 5 | saryozek
# Processing Record 20 of Set 5 | apatity
# Processing Record 21 of Set 5 | carahue
# Processing Record 22 of Set 5 | matagami
# Processing Record 23 of Set 5 | banfora
# Processing Record 24 of Set 5 | natal
# Processing Record 25 of Set 5 | nizwa
# Processing Record 26 of Set 5 | olafsvik
# Processing Record 27 of Set 5 | dudinka
# Processing Record 28 of Set 5 | kiranur
# Processing Record 29 of Set 5 | porto novo
# Processing Record 30 of Set 5 | qarqin
# Processing Record 31 of Set 5 | roald
# Processing Record 32 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 5 | les cayes
# Processing Record 34 of Set 5 | bonthe
# Processing Record 35 of Set 5 | borisoglebskiy
# Processing Record 36 of Set 5 | kerouane
# Processing Record 37 of Set 5 | rawson
# Processing Record 38 of Set 5 | kandi
# Processing Record 39 of Set 5 | hofn
# Processing Record 40 of Set 5 | bengkulu
# Processing Record 41 of Set 5 | mitsamiouli
# Processing Record 42 of Set 5 | ascension
# Processing Record 43 of Set 5 | lethem
# Processing Record 44 of Set 5 | salalah
# Processing Record 45 of Set 5 | saint-augustin
# Processing Record 46 of Set 5 | rauma
# Processing Record 47 of Set 5 | magadi
# Processing Record 48 of Set 5 | geraldton
# Processing Record 49 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 5 | libertador general san martin
# Processing Record 1 of Set 6 | saint-felicien
# Processing Record 2 of Set 6 | karpathos
# Processing Record 3 of Set 6 | ginir
# Processing Record 4 of Set 6 | olkhovka
# Processing Record 5 of Set 6 | richards bay
# Processing Record 6 of Set 6 | san cristobal
# Processing Record 7 of Set 6 | timbiqui
# Processing Record 8 of Set 6 | mende
# Processing Record 9 of Set 6 | urengoy
# Processing Record 10 of Set 6 | kudahuvadhoo
# Processing Record 11 of Set 6 | gornopravdinsk
# Processing Record 12 of Set 6 | atar
# Processing Record 13 of Set 6 | oranjemund
# Processing Record 14 of Set 6 | parrita
# Processing Record 15 of Set 6 | adre
# Processing Record 16 of Set 6 | tupelo
# Processing Record 17 of Set 6 | katiola
# Processing Record 18 of Set 6 | asino
# Processing Record 19 of Set 6 | san andres
# Processing Record 20 of Set 6 | touros
# Processing Record 21 of Set 6 | peterhead
# Processing Record 22 of Set 6 | sao filipe
# Processing Record 23 of Set 6 | razole
# Processing Record 24 of Set 6 | galle
# Processing Record 25 of Set 6 | talcahuano
# Processing Record 26 of Set 6 | matara
# Processing Record 27 of Set 6 | bayji
# Processing Record 28 of Set 6 | kulhudhuffushi
# Processing Record 29 of Set 6 | el molino
# Processing Record 30 of Set 6 | contamana
# Processing Record 31 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 32 of Set 6 | tomelloso
# Processing Record 33 of Set 6 | ugoofaaru
# Processing Record 34 of Set 6 | dekar
# Processing Record 35 of Set 6 | talnakh
# Processing Record 36 of Set 6 | zuwarah
# Processing Record 37 of Set 6 | arinos
# Processing Record 38 of Set 6 | beverley
# Processing Record 39 of Set 6 | buxar
# Processing Record 40 of Set 6 | kurdzhinovo
# Processing Record 41 of Set 6 | koyilandi
# City not found. Skipping...
# Processing Record 42 of Set 6 | olinda
# Processing Record 43 of Set 6 | luwingu
# Processing Record 44 of Set 6 | eyl
# Processing Record 45 of Set 6 | nizhneivkino
# Processing Record 46 of Set 6 | grand-santi
# Processing Record 47 of Set 6 | birjand
# Processing Record 48 of Set 6 | maun
# Processing Record 49 of Set 6 | banda aceh
# Processing Record 50 of Set 6 | puerto armuelles
# Processing Record 1 of Set 7 | guarapari
# Processing Record 2 of Set 7 | altay
# Processing Record 3 of Set 7 | kerur
# Processing Record 4 of Set 7 | chhindwara
# Processing Record 5 of Set 7 | sayyan
# Processing Record 6 of Set 7 | zolotyy potik
# Processing Record 7 of Set 7 | moshupa
# Processing Record 8 of Set 7 | sinazongwe
# Processing Record 9 of Set 7 | finnsnes
# Processing Record 10 of Set 7 | grindavik
# Processing Record 11 of Set 7 | qasigiannguit
# Processing Record 12 of Set 7 | el progreso
# Processing Record 13 of Set 7 | maua
# Processing Record 14 of Set 7 | grand gaube
# Processing Record 15 of Set 7 | mirnyy
# Processing Record 16 of Set 7 | tutoia
# Processing Record 17 of Set 7 | abha
# Processing Record 18 of Set 7 | aranos
# Processing Record 19 of Set 7 | seminole
# Processing Record 20 of Set 7 | onega
# Processing Record 21 of Set 7 | paita
# Processing Record 22 of Set 7 | biltine
# Processing Record 23 of Set 7 | cayenne
# Processing Record 24 of Set 7 | karpogory
# Processing Record 25 of Set 7 | araouane
# Processing Record 26 of Set 7 | umm kaddadah
# Processing Record 27 of Set 7 | watsa
# Processing Record 28 of Set 7 | azovo
# Processing Record 29 of Set 7 | guia
# Processing Record 30 of Set 7 | goderich
# Processing Record 31 of Set 7 | general roca
# Processing Record 32 of Set 7 | blagoyevo
# Processing Record 33 of Set 7 | klaksvik
# Processing Record 34 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 35 of Set 7 | sosva
# Processing Record 36 of Set 7 | caconda
# Processing Record 37 of Set 7 | ilulissat
# Processing Record 38 of Set 7 | johi
# Processing Record 39 of Set 7 | nazca
# Processing Record 40 of Set 7 | narsaq
# Processing Record 41 of Set 7 | mao
# Processing Record 42 of Set 7 | chimore
# Processing Record 43 of Set 7 | przhevalskoye
# Processing Record 44 of Set 7 | skibbereen
# Processing Record 45 of Set 7 | gamba
# Processing Record 46 of Set 7 | uwayl
# City not found. Skipping...
# Processing Record 47 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 48 of Set 7 | kirovo-chepetsk
# Processing Record 49 of Set 7 | honningsvag
# Processing Record 50 of Set 7 | trincomalee
# Processing Record 1 of Set 8 | strezhevoy
# Processing Record 2 of Set 8 | noyabrsk
# Processing Record 3 of Set 8 | angoche
# Processing Record 4 of Set 8 | ulagan
# Processing Record 5 of Set 8 | caxito
# Processing Record 6 of Set 8 | la uribe
# City not found. Skipping...
# Processing Record 7 of Set 8 | vardo
# Processing Record 8 of Set 8 | trinidad
# Processing Record 9 of Set 8 | bara
# Processing Record 10 of Set 8 | riaba
# City not found. Skipping...
# Processing Record 11 of Set 8 | turkan
# Processing Record 12 of Set 8 | khomeynishahr
# City not found. Skipping...
# Processing Record 13 of Set 8 | pacasmayo
# Processing Record 14 of Set 8 | butembo
# Processing Record 15 of Set 8 | mecca
# Processing Record 16 of Set 8 | myatlevo
# Processing Record 17 of Set 8 | veraval
# Processing Record 18 of Set 8 | maroantsetra
# Processing Record 19 of Set 8 | kibaya
# Processing Record 20 of Set 8 | port washington
# Processing Record 21 of Set 8 | san juan del sur
# Processing Record 22 of Set 8 | necochea
# Processing Record 23 of Set 8 | nantucket
# Processing Record 24 of Set 8 | iqaluit
# Processing Record 25 of Set 8 | burica
# City not found. Skipping...
# Processing Record 26 of Set 8 | sholokhovskiy
# Processing Record 27 of Set 8 | saint-joseph
# Processing Record 28 of Set 8 | dalvik
# Processing Record 29 of Set 8 | rio gallegos
# Processing Record 30 of Set 8 | buraydah
# Processing Record 31 of Set 8 | bud
# Processing Record 32 of Set 8 | qandala
# Processing Record 33 of Set 8 | plettenberg bay
# Processing Record 34 of Set 8 | filadelfia
# Processing Record 35 of Set 8 | kibala
# Processing Record 36 of Set 8 | manitouwadge
# Processing Record 37 of Set 8 | sukhobezvodnoye
# Processing Record 38 of Set 8 | jaicos
# Processing Record 39 of Set 8 | xudat
# Processing Record 40 of Set 8 | kyzyl-suu
# Processing Record 41 of Set 8 | kharitonovo
# Processing Record 42 of Set 8 | progreso
# Processing Record 43 of Set 8 | malatya
# Processing Record 44 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 45 of Set 8 | kaspiyskiy
# Processing Record 46 of Set 8 | yayva
# Processing Record 47 of Set 8 | iki-burul
# Processing Record 48 of Set 8 | staryy nadym
# Processing Record 49 of Set 8 | midyat
# Processing Record 50 of Set 8 | okahandja
# Processing Record 1 of Set 9 | salazie
# Processing Record 2 of Set 9 | bay roberts
# Processing Record 3 of Set 9 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 4 of Set 9 | aqtobe
# Processing Record 5 of Set 9 | le vauclin
# Processing Record 6 of Set 9 | sargatskoye
# Processing Record 7 of Set 9 | dwarka
# Processing Record 8 of Set 9 | visby
# Processing Record 9 of Set 9 | gravdal
# Processing Record 10 of Set 9 | terrace bay
# Processing Record 11 of Set 9 | breza
# Processing Record 12 of Set 9 | yenagoa
# Processing Record 13 of Set 9 | morshansk
# Processing Record 14 of Set 9 | mehran
# Processing Record 15 of Set 9 | salaga
# Processing Record 16 of Set 9 | rocha
# Processing Record 17 of Set 9 | kashi
# Processing Record 18 of Set 9 | dabhol
# Processing Record 19 of Set 9 | arlit
# Processing Record 20 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 9 | cap malheureux
# Processing Record 22 of Set 9 | chodavaram
# Processing Record 23 of Set 9 | santa maria
# Processing Record 24 of Set 9 | barcarena
# Processing Record 25 of Set 9 | las palmas
# Processing Record 26 of Set 9 | quatre cocos
# Processing Record 27 of Set 9 | jamui
# Processing Record 28 of Set 9 | songea
# Processing Record 29 of Set 9 | jahrom
# City not found. Skipping...
# Processing Record 30 of Set 9 | sinop
# Processing Record 31 of Set 9 | talara
# Processing Record 32 of Set 9 | osakarovka
# Processing Record 33 of Set 9 | boralday
# Processing Record 34 of Set 9 | karabulak
# Processing Record 35 of Set 9 | santa ana
# Processing Record 36 of Set 9 | safranbolu
# Processing Record 37 of Set 9 | koslan
# Processing Record 38 of Set 9 | sandnessjoen
# Processing Record 39 of Set 9 | tabuk
# Processing Record 40 of Set 9 | klyuchi
# Processing Record 41 of Set 9 | tamandare
# Processing Record 42 of Set 9 | laukaa
# Processing Record 43 of Set 9 | porto velho
# Processing Record 44 of Set 9 | maniitsoq
# Processing Record 45 of Set 9 | vila do maio
# Processing Record 46 of Set 9 | antofagasta
# Processing Record 47 of Set 9 | guapi
# Processing Record 48 of Set 9 | bulawayo
# Processing Record 49 of Set 9 | jinka
# Processing Record 50 of Set 9 | karanja
# Processing Record 1 of Set 10 | abdanan
# Processing Record 2 of Set 10 | severnyy
# Processing Record 3 of Set 10 | atasu
# Processing Record 4 of Set 10 | emirdag
# Processing Record 5 of Set 10 | prado
# Processing Record 6 of Set 10 | saint-francois
# Processing Record 7 of Set 10 | ornskoldsvik
# Processing Record 8 of Set 10 | talgar
# Processing Record 9 of Set 10 | manali
# Processing Record 10 of Set 10 | bubaque
# Processing Record 11 of Set 10 | pidhorodne
# Processing Record 12 of Set 10 | kindu
# Processing Record 13 of Set 10 | carnarvon
# Processing Record 14 of Set 10 | virginia beach
# Processing Record 15 of Set 10 | san rafael del sur
# Processing Record 16 of Set 10 | kassala
# Processing Record 17 of Set 10 | florence
# Processing Record 18 of Set 10 | saharsa
# Processing Record 19 of Set 10 | taft
# Processing Record 20 of Set 10 | harper
# Processing Record 21 of Set 10 | chapais
# Processing Record 22 of Set 10 | chilca
# Processing Record 23 of Set 10 | puerto ayora
# Processing Record 24 of Set 10 | nuuk
# Processing Record 25 of Set 10 | saint-pierre
# Processing Record 26 of Set 10 | klooga
# Processing Record 27 of Set 10 | batouri
# Processing Record 28 of Set 10 | ouro preto do oeste
# Processing Record 29 of Set 10 | burayevo
# Processing Record 30 of Set 10 | kismayo
# Processing Record 31 of Set 10 | nouadhibou
# Processing Record 32 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 10 | bati
# Processing Record 34 of Set 10 | bandarbeyla
# Processing Record 35 of Set 10 | miajadas
# Processing Record 36 of Set 10 | henties bay
# Processing Record 37 of Set 10 | itupiranga
# Processing Record 38 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 39 of Set 10 | rorvik
# Processing Record 40 of Set 10 | sehithwa
# Processing Record 41 of Set 10 | taoudenni
# Processing Record 42 of Set 10 | comodoro rivadavia
# Processing Record 43 of Set 10 | asansol
# Processing Record 44 of Set 10 | bodrum
# Processing Record 45 of Set 10 | moose factory
# Processing Record 46 of Set 10 | khorixas
# Processing Record 47 of Set 10 | nassogne
# Processing Record 48 of Set 10 | masvingo
# Processing Record 49 of Set 10 | fitchburg
# Processing Record 50 of Set 10 | beira
# Processing Record 1 of Set 11 | alampur
# Processing Record 2 of Set 11 | adrar
# Processing Record 3 of Set 11 | domoni
# Processing Record 4 of Set 11 | surt
# Processing Record 5 of Set 11 | yefimovskiy
# City not found. Skipping...
# Processing Record 6 of Set 11 | bonavista
# Processing Record 7 of Set 11 | sirjan
# Processing Record 8 of Set 11 | thohoyandou
# Processing Record 9 of Set 11 | syracuse
# Processing Record 10 of Set 11 | le moule
# Processing Record 11 of Set 11 | chitral
# Processing Record 12 of Set 11 | nuneaton
# Processing Record 13 of Set 11 | livingstonia
# Processing Record 14 of Set 11 | valparaiso
# Processing Record 15 of Set 11 | saint george
# Processing Record 16 of Set 11 | asayita
# City not found. Skipping...
# Processing Record 17 of Set 11 | dublin
# Processing Record 18 of Set 11 | dromolaxia
# Processing Record 19 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 11 | pando
# Processing Record 21 of Set 11 | dzilam gonzalez
# Processing Record 22 of Set 11 | marienburg
# Processing Record 23 of Set 11 | la rioja
# Processing Record 24 of Set 11 | ostrovnoy
# Processing Record 25 of Set 11 | dondo
# Processing Record 26 of Set 11 | kachikau
# City not found. Skipping...
# Processing Record 27 of Set 11 | abeche
# Processing Record 28 of Set 11 | ofaqim
# Processing Record 29 of Set 11 | iralaya
# Processing Record 30 of Set 11 | mayor pablo lagerenza
# Processing Record 31 of Set 11 | koulikoro
# Processing Record 32 of Set 11 | carutapera

# %%
#Add the data to a new DataFrame.

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

new_column_order = ["City", "Country", "Lat", "Lng","Date","Max Temp","Humidity","Cloudiness","Wind Speed"]
city_data_df = city_data_df[new_column_order]

city_data_df.head(10)

# %%
#Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# Create the output file (CSV).
output_data_file = "Weather_database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
