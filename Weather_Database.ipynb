# %% [markdown]
# Weather_database

# %% [markdown]
# Deliverable 1

# %%
#Importing libraries
import random
import pandas as pd
import numpy as np

# %%
#Create a new set of 2,000 random latitudes and longitudes
lats= []
lngs= []

lats = np.random.uniform(90,-90, size=2000)
lngs = np.random.uniform(90,-90, size=2000)

lats_lngs = zip(lats, lngs)

coordinates = list(lats_lngs)

# %%
# Get the nearest city using the citipy module
from citipy import citipy


# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
print(len(cities))
# Out:
# 745

# %%
#Perform an API call with the OpenWeatherMap

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an endpoint URL for a city.
city_url = url + "&q=" + "boston"

# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 69.85,
#   'feels_like': 68.61,
#   'temp_min': 64.17,
#   'temp_max': 73.09,
#   'pressure': 1014,
#   'humidity': 44},
#  'visibility': 10000,
#  'wind': {'speed': 6.53, 'deg': 294, 'gust': 20.67},
#  'clouds': {'all': 0},
#  'dt': 1655171912,
#  'sys': {'type': 2,
#   'id': 2009921,
#   'country': 'US',
#   'sunrise': 1655111216,
#   'sunset': 1655166110},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Retrieve the following information from the API call
##Latitude and longitude
##Maximum temperature
##Percent humidity
##Percent cloudiness
##Wind speed
##Weather description (for example, clouds, fog, light rain, clear sky)


# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime


# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1



# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | eyl
# Processing Record 3 of Set 1 | los llanos de aridane
# Processing Record 4 of Set 1 | port-gentil
# Processing Record 5 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | vila franca do campo
# Processing Record 8 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 1 | klaksvik
# Processing Record 10 of Set 1 | upernavik
# Processing Record 11 of Set 1 | dikson
# Processing Record 12 of Set 1 | arnprior
# Processing Record 13 of Set 1 | afmadu
# City not found. Skipping...
# Processing Record 14 of Set 1 | belmonte
# Processing Record 15 of Set 1 | lesnoy
# Processing Record 16 of Set 1 | hartselle
# Processing Record 17 of Set 1 | havoysund
# Processing Record 18 of Set 1 | torbay
# Processing Record 19 of Set 1 | vila velha
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | arraial do cabo
# Processing Record 22 of Set 1 | tasiilaq
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | richards bay
# Processing Record 25 of Set 1 | lima
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | nioro
# Processing Record 30 of Set 1 | georgetown
# Processing Record 31 of Set 1 | moyobamba
# Processing Record 32 of Set 1 | shelburne
# Processing Record 33 of Set 1 | bonthe
# Processing Record 34 of Set 1 | codrington
# Processing Record 35 of Set 1 | asuncion
# Processing Record 36 of Set 1 | krasnoselkup
# Processing Record 37 of Set 1 | dingle
# Processing Record 38 of Set 1 | souillac
# Processing Record 39 of Set 1 | cidreira
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 42 of Set 1 | santiago del estero
# Processing Record 43 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 45 of Set 1 | arlit
# Processing Record 46 of Set 1 | caravelas
# Processing Record 47 of Set 1 | nanortalik
# Processing Record 48 of Set 1 | talara
# Processing Record 49 of Set 1 | ji-parana
# City not found. Skipping...
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | saint-philippe
# Processing Record 2 of Set 2 | faya
# Processing Record 3 of Set 2 | pula
# Processing Record 4 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 2 | rocha
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | bambous virieux
# Processing Record 8 of Set 2 | manaus
# Processing Record 9 of Set 2 | talcahuano
# Processing Record 10 of Set 2 | garowe
# Processing Record 11 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 2 | ituni
# City not found. Skipping...
# Processing Record 13 of Set 2 | shache
# Processing Record 14 of Set 2 | yar-sale
# Processing Record 15 of Set 2 | emba
# Processing Record 16 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 2 | lerwick
# Processing Record 18 of Set 2 | salo
# Processing Record 19 of Set 2 | qibili
# City not found. Skipping...
# Processing Record 20 of Set 2 | roald
# Processing Record 21 of Set 2 | cap malheureux
# Processing Record 22 of Set 2 | zaraza
# Processing Record 23 of Set 2 | ilebo
# Processing Record 24 of Set 2 | cayenne
# Processing Record 25 of Set 2 | punta arenas
# Processing Record 26 of Set 2 | adwa
# Processing Record 27 of Set 2 | grand gaube
# Processing Record 28 of Set 2 | lebu
# Processing Record 29 of Set 2 | bredasdorp
# Processing Record 30 of Set 2 | takoradi
# Processing Record 31 of Set 2 | mar del plata
# Processing Record 32 of Set 2 | goldsboro
# Processing Record 33 of Set 2 | liverpool
# Processing Record 34 of Set 2 | bolobo
# Processing Record 35 of Set 2 | olafsvik
# Processing Record 36 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 2 | itatinga
# Processing Record 38 of Set 2 | rostovka
# Processing Record 39 of Set 2 | taywarah
# Processing Record 40 of Set 2 | kralendijk
# Processing Record 41 of Set 2 | zlatoust
# Processing Record 42 of Set 2 | myrtle beach
# Processing Record 43 of Set 2 | manaure
# Processing Record 44 of Set 2 | mizdah
# Processing Record 45 of Set 2 | puerto ayacucho
# Processing Record 46 of Set 2 | nacala
# Processing Record 47 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 48 of Set 2 | tsagan aman
# Processing Record 49 of Set 2 | leshukonskoye
# Processing Record 50 of Set 2 | mount pleasant
# Processing Record 1 of Set 3 | hithadhoo
# Processing Record 2 of Set 3 | hanko
# Processing Record 3 of Set 3 | sept-iles
# Processing Record 4 of Set 3 | ostrovnoy
# Processing Record 5 of Set 3 | tanda
# Processing Record 6 of Set 3 | lardos
# Processing Record 7 of Set 3 | high rock
# Processing Record 8 of Set 3 | axim
# Processing Record 9 of Set 3 | zaysan
# Processing Record 10 of Set 3 | santa cruz
# Processing Record 11 of Set 3 | maroantsetra
# Processing Record 12 of Set 3 | marzuq
# Processing Record 13 of Set 3 | sirnak
# Processing Record 14 of Set 3 | santa maria
# Processing Record 15 of Set 3 | khanpur
# Processing Record 16 of Set 3 | subaytilah
# City not found. Skipping...
# Processing Record 17 of Set 3 | necochea
# Processing Record 18 of Set 3 | bafq
# Processing Record 19 of Set 3 | laguna
# Processing Record 20 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 21 of Set 3 | colares
# Processing Record 22 of Set 3 | upington
# Processing Record 23 of Set 3 | itarema
# Processing Record 24 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 3 | crixas
# Processing Record 26 of Set 3 | zonalnaya stantsiya
# Processing Record 27 of Set 3 | lagos
# Processing Record 28 of Set 3 | beloha
# Processing Record 29 of Set 3 | mikhaylovka
# Processing Record 30 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 32 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 3 | tovarkovskiy
# Processing Record 34 of Set 3 | gewane
# Processing Record 35 of Set 3 | lidorikion
# City not found. Skipping...
# Processing Record 36 of Set 3 | bubaque
# Processing Record 37 of Set 3 | port elizabeth
# Processing Record 38 of Set 3 | save
# Processing Record 39 of Set 3 | buenos aires
# Processing Record 40 of Set 3 | mianwali
# Processing Record 41 of Set 3 | tarrafal
# Processing Record 42 of Set 3 | vigeland
# Processing Record 43 of Set 3 | inhambane
# Processing Record 44 of Set 3 | mahebourg
# Processing Record 45 of Set 3 | parkersburg
# Processing Record 46 of Set 3 | kiruna
# Processing Record 47 of Set 3 | mecca
# Processing Record 48 of Set 3 | fonte boa
# Processing Record 49 of Set 3 | rudbar
# Processing Record 50 of Set 3 | nsanje
# Processing Record 1 of Set 4 | pietersburg
# Processing Record 2 of Set 4 | sao filipe
# Processing Record 3 of Set 4 | ceres
# Processing Record 4 of Set 4 | sao joao da barra
# Processing Record 5 of Set 4 | eyrarbakki
# Processing Record 6 of Set 4 | felidhoo
# City not found. Skipping...
# Processing Record 7 of Set 4 | chuy
# Processing Record 8 of Set 4 | wamba
# Processing Record 9 of Set 4 | bathsheba
# Processing Record 10 of Set 4 | sambava
# Processing Record 11 of Set 4 | karmaskaly
# Processing Record 12 of Set 4 | ponta do sol
# Processing Record 13 of Set 4 | ouadda
# Processing Record 14 of Set 4 | harper
# Processing Record 15 of Set 4 | gazanjyk
# Processing Record 16 of Set 4 | luanda
# Processing Record 17 of Set 4 | comodoro rivadavia
# Processing Record 18 of Set 4 | iqaluit
# Processing Record 19 of Set 4 | victoria
# Processing Record 20 of Set 4 | sinnamary
# Processing Record 21 of Set 4 | chapais
# Processing Record 22 of Set 4 | banikoara
# Processing Record 23 of Set 4 | east london
# Processing Record 24 of Set 4 | iskateley
# Processing Record 25 of Set 4 | rio gallegos
# Processing Record 26 of Set 4 | turayf
# Processing Record 27 of Set 4 | coihaique
# Processing Record 28 of Set 4 | ribeira grande
# Processing Record 29 of Set 4 | presidencia roque saenz pena
# Processing Record 30 of Set 4 | margate
# Processing Record 31 of Set 4 | uporovo
# Processing Record 32 of Set 4 | pailon
# Processing Record 33 of Set 4 | diego de almagro
# Processing Record 34 of Set 4 | qrendi
# Processing Record 35 of Set 4 | clyde river
# Processing Record 36 of Set 4 | hamilton
# Processing Record 37 of Set 4 | bodden town
# Processing Record 38 of Set 4 | san cristobal
# Processing Record 39 of Set 4 | gat
# Processing Record 40 of Set 4 | narsaq
# Processing Record 41 of Set 4 | rincon
# Processing Record 42 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 4 | hambantota
# Processing Record 44 of Set 4 | bengkulu
# Processing Record 45 of Set 4 | chelmza
# Processing Record 46 of Set 4 | marovoay
# Processing Record 47 of Set 4 | san rafael
# Processing Record 48 of Set 4 | abu samrah
# Processing Record 49 of Set 4 | natal
# Processing Record 50 of Set 4 | kruisfontein
# Processing Record 1 of Set 5 | thinadhoo
# Processing Record 2 of Set 5 | vestmannaeyjar
# Processing Record 3 of Set 5 | tibati
# Processing Record 4 of Set 5 | ambilobe
# Processing Record 5 of Set 5 | thunder bay
# Processing Record 6 of Set 5 | viytivka
# Processing Record 7 of Set 5 | iralaya
# Processing Record 8 of Set 5 | samur
# Processing Record 9 of Set 5 | damghan
# Processing Record 10 of Set 5 | longyearbyen
# Processing Record 11 of Set 5 | urengoy
# Processing Record 12 of Set 5 | sazonovo
# Processing Record 13 of Set 5 | afua
# Processing Record 14 of Set 5 | sur
# Processing Record 15 of Set 5 | kribi
# Processing Record 16 of Set 5 | aswan
# Processing Record 17 of Set 5 | jutai
# Processing Record 18 of Set 5 | bereda
# Processing Record 19 of Set 5 | namibe
# Processing Record 20 of Set 5 | salalah
# Processing Record 21 of Set 5 | bud
# Processing Record 22 of Set 5 | atbasar
# Processing Record 23 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 24 of Set 5 | mogadishu
# Processing Record 25 of Set 5 | chardara
# Processing Record 26 of Set 5 | pitkyaranta
# Processing Record 27 of Set 5 | lalsot
# Processing Record 28 of Set 5 | husavik
# Processing Record 29 of Set 5 | gamba
# Processing Record 30 of Set 5 | eirunepe
# Processing Record 31 of Set 5 | chokwe
# Processing Record 32 of Set 5 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 33 of Set 5 | breytovo
# Processing Record 34 of Set 5 | dondo
# Processing Record 35 of Set 5 | mazagao
# Processing Record 36 of Set 5 | saint-georges
# Processing Record 37 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 38 of Set 5 | saint anthony
# Processing Record 39 of Set 5 | tabou
# Processing Record 40 of Set 5 | plettenberg bay
# Processing Record 41 of Set 5 | znamenskoye
# Processing Record 42 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 43 of Set 5 | upata
# Processing Record 44 of Set 5 | lichinga
# Processing Record 45 of Set 5 | buchanan
# Processing Record 46 of Set 5 | bezhetsk
# Processing Record 47 of Set 5 | saldanha
# Processing Record 48 of Set 5 | hukuntsi
# Processing Record 49 of Set 5 | nykobing
# City not found. Skipping...
# Processing Record 50 of Set 5 | north bay
# Processing Record 1 of Set 6 | suluq
# Processing Record 2 of Set 6 | maniitsoq
# Processing Record 3 of Set 6 | luderitz
# Processing Record 4 of Set 6 | digha
# Processing Record 5 of Set 6 | birnin kebbi
# Processing Record 6 of Set 6 | nyagan
# Processing Record 7 of Set 6 | taltal
# Processing Record 8 of Set 6 | bonavista
# Processing Record 9 of Set 6 | berlevag
# Processing Record 10 of Set 6 | salinas
# Processing Record 11 of Set 6 | lupiro
# Processing Record 12 of Set 6 | atar
# Processing Record 13 of Set 6 | soroti
# Processing Record 14 of Set 6 | vestmanna
# Processing Record 15 of Set 6 | coquimbo
# Processing Record 16 of Set 6 | tazovskiy
# Processing Record 17 of Set 6 | goose creek
# Processing Record 18 of Set 6 | idritsa
# Processing Record 19 of Set 6 | bajo baudo
# City not found. Skipping...
# Processing Record 20 of Set 6 | camacupa
# Processing Record 21 of Set 6 | sao gabriel da cachoeira
# Processing Record 22 of Set 6 | matagami
# Processing Record 23 of Set 6 | mau aima
# City not found. Skipping...
# Processing Record 24 of Set 6 | kapoeta
# Processing Record 25 of Set 6 | strezhevoy
# Processing Record 26 of Set 6 | kavaratti
# Processing Record 27 of Set 6 | la macarena
# Processing Record 28 of Set 6 | antibes
# Processing Record 29 of Set 6 | bandarbeyla
# Processing Record 30 of Set 6 | castro
# Processing Record 31 of Set 6 | kutum
# Processing Record 32 of Set 6 | nakuru
# Processing Record 33 of Set 6 | angra
# City not found. Skipping...
# Processing Record 34 of Set 6 | ilhabela
# Processing Record 35 of Set 6 | imbituba
# Processing Record 36 of Set 6 | shetpe
# Processing Record 37 of Set 6 | santa rosa
# Processing Record 38 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 6 | russkaya polyana
# Processing Record 40 of Set 6 | molokovo
# Processing Record 41 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 42 of Set 6 | korla
# Processing Record 43 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 6 | nuuk
# Processing Record 45 of Set 6 | borba
# Processing Record 46 of Set 6 | adigeni
# Processing Record 47 of Set 6 | bainbridge
# Processing Record 48 of Set 6 | romanovka
# Processing Record 49 of Set 6 | mahanoro
# Processing Record 50 of Set 6 | dzilam gonzalez
# Processing Record 1 of Set 7 | sao miguel do araguaia
# Processing Record 2 of Set 7 | ntoum
# Processing Record 3 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 7 | lago da pedra
# Processing Record 5 of Set 7 | christiansburg
# Processing Record 6 of Set 7 | najran
# Processing Record 7 of Set 7 | den helder
# Processing Record 8 of Set 7 | gambela
# Processing Record 9 of Set 7 | abu dhabi
# Processing Record 10 of Set 7 | shiraz
# Processing Record 11 of Set 7 | port-cartier
# Processing Record 12 of Set 7 | bauska
# Processing Record 13 of Set 7 | tasnad
# Processing Record 14 of Set 7 | naron
# Processing Record 15 of Set 7 | siderno
# Processing Record 16 of Set 7 | goderich
# Processing Record 17 of Set 7 | road town
# Processing Record 18 of Set 7 | berbera
# Processing Record 19 of Set 7 | saint-augustin
# Processing Record 20 of Set 7 | grindavik
# Processing Record 21 of Set 7 | weligama
# Processing Record 22 of Set 7 | hofn
# Processing Record 23 of Set 7 | cockburn town
# Processing Record 24 of Set 7 | baikunthpur
# Processing Record 25 of Set 7 | edd
# Processing Record 26 of Set 7 | beira
# Processing Record 27 of Set 7 | qasigiannguit
# Processing Record 28 of Set 7 | pangody
# Processing Record 29 of Set 7 | quatre cocos
# Processing Record 30 of Set 7 | panjab
# Processing Record 31 of Set 7 | terneuzen
# Processing Record 32 of Set 7 | halifax
# Processing Record 33 of Set 7 | misratah
# Processing Record 34 of Set 7 | sao miguel dos campos
# Processing Record 35 of Set 7 | sena madureira
# Processing Record 36 of Set 7 | walvis bay
# Processing Record 37 of Set 7 | gangotri
# City not found. Skipping...
# Processing Record 38 of Set 7 | dembi dolo
# Processing Record 39 of Set 7 | conakry
# Processing Record 40 of Set 7 | wanlaweyn
# Processing Record 41 of Set 7 | solsvik
# City not found. Skipping...
# Processing Record 42 of Set 7 | ancud
# Processing Record 43 of Set 7 | pangnirtung
# Processing Record 44 of Set 7 | bonwapitse
# Processing Record 45 of Set 7 | morondava
# Processing Record 46 of Set 7 | ilheus
# Processing Record 47 of Set 7 | quibdo
# Processing Record 48 of Set 7 | andijon
# Processing Record 49 of Set 7 | dasoguz
# Processing Record 50 of Set 7 | padang
# Processing Record 1 of Set 8 | diapaga
# Processing Record 2 of Set 8 | puerto escondido
# Processing Record 3 of Set 8 | minab
# Processing Record 4 of Set 8 | wukari
# Processing Record 5 of Set 8 | pitimbu
# Processing Record 6 of Set 8 | ponta grossa
# Processing Record 7 of Set 8 | omboue
# Processing Record 8 of Set 8 | wajid
# Processing Record 9 of Set 8 | minsk
# Processing Record 10 of Set 8 | potgietersrus
# City not found. Skipping...
# Processing Record 11 of Set 8 | kibre mengist
# Processing Record 12 of Set 8 | quelimane
# Processing Record 13 of Set 8 | tabuk
# Processing Record 14 of Set 8 | tshikapa
# Processing Record 15 of Set 8 | paragominas
# Processing Record 16 of Set 8 | miasskoye
# Processing Record 17 of Set 8 | meulaboh
# Processing Record 18 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 19 of Set 8 | agadez
# Processing Record 20 of Set 8 | rapar
# Processing Record 21 of Set 8 | linhares
# Processing Record 22 of Set 8 | erzurum
# Processing Record 23 of Set 8 | saint-pierre
# Processing Record 24 of Set 8 | maragogi
# Processing Record 25 of Set 8 | scarborough
# Processing Record 26 of Set 8 | malazgirt
# Processing Record 27 of Set 8 | cape canaveral
# Processing Record 28 of Set 8 | barry
# Processing Record 29 of Set 8 | kulhudhuffushi
# Processing Record 30 of Set 8 | matadi
# Processing Record 31 of Set 8 | nevsehir
# Processing Record 32 of Set 8 | makat
# Processing Record 33 of Set 8 | kidal
# Processing Record 34 of Set 8 | bibbiena
# Processing Record 35 of Set 8 | lagoa
# Processing Record 36 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 37 of Set 8 | abu zabad
# Processing Record 38 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 39 of Set 8 | contamana
# Processing Record 40 of Set 8 | touros
# Processing Record 41 of Set 8 | tobermory
# Processing Record 42 of Set 8 | ugoofaaru
# Processing Record 43 of Set 8 | bossembele
# City not found. Skipping...
# Processing Record 44 of Set 8 | koungou
# Processing Record 45 of Set 8 | grand-santi
# Processing Record 46 of Set 8 | plyussa
# Processing Record 47 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 48 of Set 8 | huarmey
# Processing Record 49 of Set 8 | hammerfest
# Processing Record 50 of Set 8 | antofagasta
# Processing Record 1 of Set 9 | suleya
# Processing Record 2 of Set 9 | beyneu
# Processing Record 3 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 9 | palmital
# Processing Record 5 of Set 9 | barahona
# Processing Record 6 of Set 9 | aksarka
# Processing Record 7 of Set 9 | lieksa
# Processing Record 8 of Set 9 | qesarya
# Processing Record 9 of Set 9 | uwayl
# City not found. Skipping...
# Processing Record 10 of Set 9 | notse
# Processing Record 11 of Set 9 | antalaha
# Processing Record 12 of Set 9 | san pedro
# Processing Record 13 of Set 9 | fasa
# Processing Record 14 of Set 9 | catamarca
# Processing Record 15 of Set 9 | belyy yar
# Processing Record 16 of Set 9 | tessalit
# Processing Record 17 of Set 9 | castries
# Processing Record 18 of Set 9 | porto murtinho
# Processing Record 19 of Set 9 | limoux
# Processing Record 20 of Set 9 | vardo
# Processing Record 21 of Set 9 | bilma
# Processing Record 22 of Set 9 | ponta delgada
# Processing Record 23 of Set 9 | hobyo
# Processing Record 24 of Set 9 | alekseyevka
# Processing Record 25 of Set 9 | angoche
# Processing Record 26 of Set 9 | skotterud
# Processing Record 27 of Set 9 | berasia
# Processing Record 28 of Set 9 | camacha
# Processing Record 29 of Set 9 | calimete
# Processing Record 30 of Set 9 | teguldet
# Processing Record 31 of Set 9 | san borja
# Processing Record 32 of Set 9 | praia da vitoria
# Processing Record 33 of Set 9 | marathon
# Processing Record 34 of Set 9 | mesopotamia
# Processing Record 35 of Set 9 | sidi ali
# Processing Record 36 of Set 9 | cristalina
# Processing Record 37 of Set 9 | ciudad bolivar
# Processing Record 38 of Set 9 | narnaund
# Processing Record 39 of Set 9 | jeremie
# Processing Record 40 of Set 9 | san carlos de bariloche
# Processing Record 41 of Set 9 | jalu
# Processing Record 42 of Set 9 | zahir pir
# Processing Record 43 of Set 9 | puquio
# Processing Record 44 of Set 9 | chipinge
# Processing Record 45 of Set 9 | nicoya
# Processing Record 46 of Set 9 | straumen
# Processing Record 47 of Set 9 | san ramon
# Processing Record 48 of Set 9 | jabinyanah
# Processing Record 49 of Set 9 | orguz
# Processing Record 50 of Set 9 | locri
# Processing Record 1 of Set 10 | valdosta
# Processing Record 2 of Set 10 | kaspiysk
# Processing Record 3 of Set 10 | mahon
# Processing Record 4 of Set 10 | ilulissat
# Processing Record 5 of Set 10 | makaryev
# Processing Record 6 of Set 10 | groningen
# Processing Record 7 of Set 10 | talnakh
# Processing Record 8 of Set 10 | magole
# Processing Record 9 of Set 10 | san luis
# Processing Record 10 of Set 10 | toktogul
# Processing Record 11 of Set 10 | brewster
# Processing Record 12 of Set 10 | tromso
# Processing Record 13 of Set 10 | rio esteban
# Processing Record 14 of Set 10 | neyshabur
# Processing Record 15 of Set 10 | tambura
# Processing Record 16 of Set 10 | plouzane
# Processing Record 17 of Set 10 | barentu
# Processing Record 18 of Set 10 | mampong
# Processing Record 19 of Set 10 | elesbao veloso
# Processing Record 20 of Set 10 | manzil tamim
# City not found. Skipping...
# Processing Record 21 of Set 10 | torres
# Processing Record 22 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 23 of Set 10 | mangai
# Processing Record 24 of Set 10 | manakara
# Processing Record 25 of Set 10 | impfondo
# Processing Record 26 of Set 10 | kerman
# Processing Record 27 of Set 10 | constitucion
# Processing Record 28 of Set 10 | say
# Processing Record 29 of Set 10 | umm lajj
# Processing Record 30 of Set 10 | lac-megantic
# Processing Record 31 of Set 10 | kitgum
# Processing Record 32 of Set 10 | doha
# Processing Record 33 of Set 10 | ati
# Processing Record 34 of Set 10 | gweta
# Processing Record 35 of Set 10 | agarak
# Processing Record 36 of Set 10 | adrar
# Processing Record 37 of Set 10 | cotonou
# Processing Record 38 of Set 10 | skjervoy
# Processing Record 39 of Set 10 | les cayes
# Processing Record 40 of Set 10 | codo
# Processing Record 41 of Set 10 | clarence town
# Processing Record 42 of Set 10 | camocim
# Processing Record 43 of Set 10 | ramhormoz
# Processing Record 44 of Set 10 | barra patuca
# Processing Record 45 of Set 10 | copacabana
# Processing Record 46 of Set 10 | musoma
# Processing Record 47 of Set 10 | polyarnyy
# Processing Record 48 of Set 10 | southampton
# Processing Record 49 of Set 10 | kemi
# Processing Record 50 of Set 10 | manoharpur
# Processing Record 1 of Set 11 | cartagena
# Processing Record 2 of Set 11 | gilgil
# City not found. Skipping...
# Processing Record 3 of Set 11 | the valley
# Processing Record 4 of Set 11 | moche
# Processing Record 5 of Set 11 | biu
# Processing Record 6 of Set 11 | aguilas
# Processing Record 7 of Set 11 | puerto suarez
# Processing Record 8 of Set 11 | nantucket
# Processing Record 9 of Set 11 | venado tuerto
# Processing Record 10 of Set 11 | conde
# Processing Record 11 of Set 11 | karsava
# Processing Record 12 of Set 11 | dharchula
# Processing Record 13 of Set 11 | mouila
# Processing Record 14 of Set 11 | baoro
# Processing Record 15 of Set 11 | marsa matruh
# Processing Record 16 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 17 of Set 11 | alsfeld
# Processing Record 18 of Set 11 | beboto
# Processing Record 19 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 20 of Set 11 | tukrah
# Processing Record 21 of Set 11 | oussouye
# Processing Record 22 of Set 11 | casablanca
# Processing Record 23 of Set 11 | krasnoarmeysk
# Processing Record 24 of Set 11 | linares
# Processing Record 25 of Set 11 | maputo
# Processing Record 26 of Set 11 | sao domingos do maranhao
# Processing Record 27 of Set 11 | betioky
# Processing Record 28 of Set 11 | raga
# Processing Record 29 of Set 11 | diu
# Processing Record 30 of Set 11 | tutoia
# Processing Record 31 of Set 11 | east angus
# Processing Record 32 of Set 11 | kasongo-lunda
# Processing Record 33 of Set 11 | delmas
# Processing Record 34 of Set 11 | chauny
# Processing Record 35 of Set 11 | simao dias
# Processing Record 36 of Set 11 | jaru
# Processing Record 37 of Set 11 | inta
# Processing Record 38 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 11 | mapiripan
# Processing Record 40 of Set 11 | veinticinco de mayo
# Processing Record 41 of Set 11 | odweyne
# Processing Record 42 of Set 11 | puta
# Processing Record 43 of Set 11 | accra
# Processing Record 44 of Set 11 | kopervik
# Processing Record 45 of Set 11 | sharjah
# Processing Record 46 of Set 11 | jurado
# Processing Record 47 of Set 11 | nador
# Processing Record 48 of Set 11 | mana
# Processing Record 49 of Set 11 | stephenville
# Processing Record 50 of Set 11 | severnyy
# Processing Record 1 of Set 12 | puerto leguizamo
# Processing Record 2 of Set 12 | nakskov
# Processing Record 3 of Set 12 | rawson
# Processing Record 4 of Set 12 | narasannapeta
# Processing Record 5 of Set 12 | capitan miranda
# Processing Record 6 of Set 12 | gari
# Processing Record 7 of Set 12 | bucak
# Processing Record 8 of Set 12 | pashiya
# Processing Record 9 of Set 12 | sorland
# Processing Record 10 of Set 12 | salihorsk
# Processing Record 11 of Set 12 | venezuela
# Processing Record 12 of Set 12 | dhidhdhoo
# Processing Record 13 of Set 12 | carutapera
# Processing Record 14 of Set 12 | mabama
# Processing Record 15 of Set 12 | caceres
# Processing Record 16 of Set 12 | kaputa
# Processing Record 17 of Set 12 | marawi
# Processing Record 18 of Set 12 | aksay
# Processing Record 19 of Set 12 | mathathane
# Processing Record 20 of Set 12 | carnarvon
# Processing Record 21 of Set 12 | trelleborg
# Processing Record 22 of Set 12 | havre-saint-pierre
# Processing Record 23 of Set 12 | katghora
# Processing Record 24 of Set 12 | tonantins
# Processing Record 25 of Set 12 | amapa
# Processing Record 26 of Set 12 | lar gerd
# City not found. Skipping...
# Processing Record 27 of Set 12 | alta gracia
# Processing Record 28 of Set 12 | ariquemes
# Processing Record 29 of Set 12 | san juan
# Processing Record 30 of Set 12 | tyukhtet
# Processing Record 31 of Set 12 | yokadouma
# Processing Record 32 of Set 12 | yepifan
# Processing Record 33 of Set 12 | hashtrud
# Processing Record 34 of Set 12 | songea
# Processing Record 35 of Set 12 | sao jose da coroa grande
# Processing Record 36 of Set 12 | tambopata
# Processing Record 37 of Set 12 | batticaloa
# Processing Record 38 of Set 12 | abu kamal
# Processing Record 39 of Set 12 | rorvik
# Processing Record 40 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 41 of Set 12 | floro
# Processing Record 42 of Set 12 | boromo
# Processing Record 43 of Set 12 | behshahr
# Processing Record 44 of Set 12 | butler
# Processing Record 45 of Set 12 | maudaha
# Processing Record 46 of Set 12 | geraldton
# Processing Record 47 of Set 12 | ribeira brava
# Processing Record 48 of Set 12 | osa
# Processing Record 49 of Set 12 | oyon
# Processing Record 50 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 1 of Set 13 | qaqortoq
# Processing Record 2 of Set 13 | bara
# Processing Record 3 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 13 | sar-e pul
# Processing Record 5 of Set 13 | parral
# Processing Record 6 of Set 13 | niort
# Processing Record 7 of Set 13 | brandenburg
# Processing Record 8 of Set 13 | la paz
# Processing Record 9 of Set 13 | marsh harbour
# Processing Record 10 of Set 13 | auka
# Processing Record 11 of Set 13 | yellandu
# Processing Record 12 of Set 13 | lovozero
# Processing Record 13 of Set 13 | kabinda
# Processing Record 14 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 15 of Set 13 | camabatela
# Processing Record 16 of Set 13 | kandete
# Processing Record 17 of Set 13 | bol
# Processing Record 18 of Set 13 | saint-francois
# Processing Record 19 of Set 13 | chute-aux-outardes
# Processing Record 20 of Set 13 | kismayo
# Processing Record 21 of Set 13 | lamego
# Processing Record 22 of Set 13 | bam
# Processing Record 23 of Set 13 | bama
# Processing Record 24 of Set 13 | la palma
# Processing Record 25 of Set 13 | capela
# Processing Record 26 of Set 13 | albanel
# Processing Record 27 of Set 13 | aranos
# Processing Record 28 of Set 13 | axixa do tocantins
# City not found. Skipping...
# Processing Record 29 of Set 13 | pajan
# Processing Record 30 of Set 13 | ouesso
# Processing Record 31 of Set 13 | libertador general san martin
# Processing Record 32 of Set 13 | biltine
# Processing Record 33 of Set 13 | myre
# Processing Record 34 of Set 13 | surt
# Processing Record 35 of Set 13 | honningsvag
# Processing Record 36 of Set 13 | malanje
# Processing Record 37 of Set 13 | tacoronte
# Processing Record 38 of Set 13 | petushki
# Processing Record 39 of Set 13 | shawinigan
# Processing Record 40 of Set 13 | altea
# Processing Record 41 of Set 13 | seinajoki
# Processing Record 42 of Set 13 | acarau
# Processing Record 43 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 13 | thompson
# Processing Record 45 of Set 13 | huesca
# Processing Record 46 of Set 13 | opuwo
# Processing Record 47 of Set 13 | starkville
# Processing Record 48 of Set 13 | taoudenni
# Processing Record 49 of Set 13 | esil
# Processing Record 50 of Set 13 | dehloran
# Processing Record 1 of Set 14 | ronne
# Processing Record 2 of Set 14 | chakwal
# Processing Record 3 of Set 14 | chirilagua
# Processing Record 4 of Set 14 | muros
# Processing Record 5 of Set 14 | tabory
# Processing Record 6 of Set 14 | salistea de sus
# Processing Record 7 of Set 14 | visnes
# Processing Record 8 of Set 14 | apodi
# Processing Record 9 of Set 14 | kuybyshevskiy zaton
# Processing Record 10 of Set 14 | rabo de peixe
# Processing Record 11 of Set 14 | sioux lookout
# Processing Record 12 of Set 14 | mishawaka
# Processing Record 13 of Set 14 | nuevitas
# Processing Record 14 of Set 14 | nara
# Processing Record 15 of Set 14 | moyale
# Processing Record 16 of Set 14 | sokolo
# Processing Record 17 of Set 14 | sturgeon bay
# Processing Record 18 of Set 14 | mikkeli
# Processing Record 19 of Set 14 | moradabad
# Processing Record 20 of Set 14 | pelym
# Processing Record 21 of Set 14 | ciudad guayana
# Processing Record 22 of Set 14 | kedrovyy
# Processing Record 23 of Set 14 | semnan
# Processing Record 24 of Set 14 | nouadhibou
# Processing Record 25 of Set 14 | bay roberts
# Processing Record 26 of Set 14 | bahia blanca
# Processing Record 27 of Set 14 | buraydah
# Processing Record 28 of Set 14 | windsor
# Processing Record 29 of Set 14 | mendoza
# Processing Record 30 of Set 14 | karpuninskiy
# City not found. Skipping...
# Processing Record 31 of Set 14 | la plata
# Processing Record 32 of Set 14 | praia
# Processing Record 33 of Set 14 | campos altos
# Processing Record 34 of Set 14 | tsabong
# Processing Record 35 of Set 14 | bayan
# Processing Record 36 of Set 14 | turukhansk
# Processing Record 37 of Set 14 | westport
# Processing Record 38 of Set 14 | khor
# Processing Record 39 of Set 14 | ritchie
# Processing Record 40 of Set 14 | myrhorod
# Processing Record 41 of Set 14 | bahawalpur
# Processing Record 42 of Set 14 | puerto del rosario
# Processing Record 43 of Set 14 | villa carlos paz
# Processing Record 44 of Set 14 | ambad
# Processing Record 45 of Set 14 | dosso
# Processing Record 46 of Set 14 | kabale
# Processing Record 47 of Set 14 | igarapava
# Processing Record 48 of Set 14 | jaramana
# City not found. Skipping...
# Processing Record 49 of Set 14 | paso de los toros
# Processing Record 50 of Set 14 | preston
# Processing Record 1 of Set 15 | padron
# Processing Record 2 of Set 15 | kuminskiy
# Processing Record 3 of Set 15 | ketchenery
# City not found. Skipping...
# Processing Record 4 of Set 15 | chiredzi
# Processing Record 5 of Set 15 | atocha
# Processing Record 6 of Set 15 | sisimiut
# Processing Record 7 of Set 15 | mayari
# City not found. Skipping...
# Processing Record 8 of Set 15 | neuquen
# Processing Record 9 of Set 15 | banda aceh
# Processing Record 10 of Set 15 | novyy urengoy
# Processing Record 11 of Set 15 | bentiu
# Processing Record 12 of Set 15 | goure
# Processing Record 13 of Set 15 | buzmeyin
# Processing Record 14 of Set 15 | tocopilla
# Processing Record 15 of Set 15 | kalmunai
# Processing Record 16 of Set 15 | bay saint louis
# Processing Record 17 of Set 15 | himora
# City not found. Skipping...
# Processing Record 18 of Set 15 | ozgon
# City not found. Skipping...
# Processing Record 19 of Set 15 | pavagada
# Processing Record 20 of Set 15 | gao
# Processing Record 21 of Set 15 | stromness
# Processing Record 22 of Set 15 | ustka
# Processing Record 23 of Set 15 | horki
# Processing Record 24 of Set 15 | booue
# Processing Record 25 of Set 15 | sabha
# Processing Record 26 of Set 15 | ayagoz
# Processing Record 27 of Set 15 | geresk
# City not found. Skipping...
# Processing Record 28 of Set 15 | karibib
# Processing Record 29 of Set 15 | terra santa
# Processing Record 30 of Set 15 | umm kaddadah
# Processing Record 31 of Set 15 | bantry
# Processing Record 32 of Set 15 | porto walter
# Processing Record 33 of Set 15 | trairi
# Processing Record 34 of Set 15 | komsomolskiy
# Processing Record 35 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 15 | awjilah
# Processing Record 37 of Set 15 | soyo
# Processing Record 38 of Set 15 | aasiaat
# Processing Record 39 of Set 15 | aden
# Processing Record 40 of Set 15 | shaartuz
# City not found. Skipping...
# Processing Record 41 of Set 15 | methoni
# Processing Record 42 of Set 15 | komatipoort
# Processing Record 43 of Set 15 | vangaindrano
# Processing Record 44 of Set 15 | khartoum
# Processing Record 45 of Set 15 | cividale del friuli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Add the data to a new DataFrame.

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

new_column_order = ["City", "Country", "Lat", "Lng","Date","Max Temp","Humidity","Cloudiness","Wind Speed"]
city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#                     City Country      Lat      Lng                 Date  \
# 0                    Eyl      SO   7.9803  49.8164  2022-06-14 02:00:26
# 1  Los Llanos De Aridane      ES  28.6585 -17.9182  2022-06-14 02:00:27
# 2            Port-Gentil      GA  -0.7193   8.7815  2022-06-14 02:00:27
# 3   Vila Franca Do Campo      PT  37.7167 -25.4333  2022-06-14 02:00:29
# 4               Klaksvik      FO  62.2266  -6.5890  2022-06-14 02:00:31
# 5              Upernavik      GL  72.7868 -56.1549  2022-06-14 02:00:33
# 6                 Dikson      RU  73.5069  80.5464  2022-06-14 02:00:34
# 7               Arnprior      CA  45.4334 -76.3494  2022-06-14 02:00:34
# 8               Belmonte      BR -15.8631 -38.8828  2022-06-14 02:00:35
# 9                 Lesnoy      RU  57.6198  63.0784  2022-06-14 02:00:36
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     80.49        62          80       25.79
# 1     65.95        86         100        1.01
# 2     76.41        84         100       12.73
# 3     64.20        84          22        7.45
# 4     49.12        96          98       17.16
# 5     30.70        85          82        5.73
# 6     30.74        89          80       10.47
# 7     61.57        88          18        3.11
# 8     74.39        82          90       12.57
# 9     52.93        90          71        5.68

# %%
#Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# Create the output file (CSV).
output_data_file = "Weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
